# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from torchvision import transforms
from PIL import Image
import os
import numpy as np
import gc
from torch.cuda.amp import autocast, GradScaler

# %%
class FaceDataset(Dataset):
    def __init__(self, root_dir, image_size=128):  # Reduced default image size
        self.root_dir = root_dir
        self.image_size = image_size
        self.transform = transforms.Compose([
            transforms.Resize((image_size, image_size)),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ])
        self.image_files = [
            os.path.join(root_dir, f) for f in os.listdir(root_dir) 
            if f.endswith('.jpg')
        ]
    
    def __len__(self):
        return len(self.image_files)
    
    def __getitem__(self, idx):
        img_path = self.image_files[idx]
        image = Image.open(img_path).convert('RGB')
        return self.transform(image)

# %%
class MappingNetwork(nn.Module):
    def __init__(self, latent_dim=512, n_layers=4):  # Reduced number of layers
        super().__init__()
        layers = []
        for i in range(n_layers):
            layers.extend([
                nn.Linear(latent_dim, latent_dim),
                nn.LeakyReLU(0.2),
                nn.BatchNorm1d(latent_dim)
            ])
        self.mapping = nn.Sequential(*layers)
    
    def forward(self, z):
        return self.mapping(z)

# %%
class AdaIN(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.channels = channels
    
    def forward(self, x, style):
        batch = x.size(0)
        mean = x.mean(dim=[2, 3], keepdim=True)
        var = x.var(dim=[2, 3], keepdim=True) + 1e-8
        x = (x - mean) / torch.sqrt(var)
        
        style = style.view(batch, 2, self.channels, 1, 1)
        return x * style[:, 0] + style[:, 1]

# %%
class GeneratorBlock(nn.Module):
    def __init__(self, in_channels, out_channels, w_dim):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, 3, padding=1)
        self.conv2 = nn.Conv2d(out_channels, out_channels, 3, padding=1)
        self.adain1 = AdaIN(out_channels)
        self.adain2 = AdaIN(out_channels)
        self.style1 = nn.Linear(w_dim, out_channels * 2)
        self.style2 = nn.Linear(w_dim, out_channels * 2)
        
    def forward(self, x, w):
        s1 = self.style1(w)
        s2 = self.style2(w)
        
        x = self.conv1(x)
        x = self.adain1(x, s1)
        x = F.leaky_relu(x, 0.2)
        
        x = self.conv2(x)
        x = self.adain2(x, s2)
        x = F.leaky_relu(x, 0.2)
        
        return x

# %%
class StyleGANGenerator(nn.Module):
    def __init__(self, latent_dim=512, n_layers=5):  # Reduced number of layers
        super().__init__()
        self.mapping = MappingNetwork(latent_dim)
        self.constant = nn.Parameter(torch.randn(1, 512, 4, 4))
        
        # Reduced number of channels
        channels = [512, 256, 128, 64, 32, 16]
        
        self.blocks = nn.ModuleList()
        for i in range(n_layers):
            in_ch = channels[i]
            out_ch = channels[i + 1] if i < len(channels) - 1 else channels[-1]
            self.blocks.append(GeneratorBlock(in_ch, out_ch, latent_dim))
            
        self.to_rgb = nn.Conv2d(16, 3, 1)
        
    def forward(self, z):
        batch_size = z.size(0)
        w = self.mapping(z)
        x = self.constant.repeat(batch_size, 1, 1, 1)
        
        for block in self.blocks:
            x = F.interpolate(x, scale_factor=2, mode='bilinear', align_corners=False)
            x = block(x, w)
        
        return torch.tanh(self.to_rgb(x))

# %%
class StyleGANDiscriminator(nn.Module):
    def __init__(self, n_layers=5):  # Reduced number of layers
        super().__init__()
        # Reduced number of channels
        channels = [16, 32, 64, 128, 256, 512]
        
        self.from_rgb = nn.Conv2d(3, channels[0], 1)
        
        self.blocks = nn.ModuleList()
        for i in range(n_layers):
            self.blocks.append(nn.Sequential(
                nn.Conv2d(channels[i], channels[i+1], 3, padding=1),
                nn.LeakyReLU(0.2),
                nn.AvgPool2d(2)
            ))
            
        self.final = nn.Sequential(
            nn.Flatten(),
            nn.Linear(channels[-1] * 4 * 4, 1)
        )
        
    def forward(self, x):
        x = F.leaky_relu(self.from_rgb(x), 0.2)
        
        for block in self.blocks:
            x = block(x)
            
        return self.final(x)

# %%
def train_stylegan(train_dir, test_dir, num_epochs=200, batch_size=8):  # Reduced batch size
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    # Initialize dataset with smaller image size
    train_dataset = FaceDataset(train_dir, image_size=128)
    train_loader = DataLoader(
        train_dataset, 
        batch_size=batch_size, 
        shuffle=True,
        num_workers=2,  # Reduced number of workers
        pin_memory=True
    )
    
    generator = StyleGANGenerator().to(device)
    discriminator = StyleGANDiscriminator().to(device)
    
    # Use mixed precision training
    scaler = GradScaler()
    
    # Use different learning rates for generator and discriminator
    g_optimizer = torch.optim.Adam(generator.parameters(), lr=0.0001, betas=(0.0, 0.99))
    d_optimizer = torch.optim.Adam(discriminator.parameters(), lr=0.0001, betas=(0.0, 0.99))
    
    # Learning rate schedulers
    g_scheduler = torch.optim.lr_scheduler.ExponentialLR(g_optimizer, gamma=0.99)
    d_scheduler = torch.optim.lr_scheduler.ExponentialLR(d_optimizer, gamma=0.99)
    
    # Track losses for plotting
    d_losses = []
    g_losses = []
    
    for epoch in range(num_epochs):
        epoch_d_loss = 0
        epoch_g_loss = 0
        for batch_idx, real_images in enumerate(train_loader):
            real_images = real_images.to(device)
            batch_size = real_images.size(0)
            
            # Clear cache periodically
            if batch_idx % 10 == 0:
                torch.cuda.empty_cache()
            
            # Train Discriminator
            with autocast():
                d_optimizer.zero_grad()
                
                label_real = torch.ones(batch_size, 1).to(device)
                label_fake = torch.zeros(batch_size, 1).to(device)
                
                d_output_real = discriminator(real_images)
                d_loss_real = F.binary_cross_entropy_with_logits(d_output_real, label_real)
                
                z = torch.randn(batch_size, 512).to(device)
                fake_images = generator(z)
                d_output_fake = discriminator(fake_images.detach())
                d_loss_fake = F.binary_cross_entropy_with_logits(d_output_fake, label_fake)
                
                d_loss = d_loss_real + d_loss_fake
            
            scaler.scale(d_loss).backward()
            scaler.step(d_optimizer)
            
            # Train Generator
            with autocast():
                g_optimizer.zero_grad()
                
                d_output_fake = discriminator(fake_images)
                g_loss = F.binary_cross_entropy_with_logits(d_output_fake, label_real)
            
            scaler.scale(g_loss).backward()
            scaler.step(g_optimizer)
            
            scaler.update()
            
            # Accumulate losses
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            
            if batch_idx % 50 == 0:
                print(f'Epoch [{epoch}/{num_epochs}] Batch [{batch_idx}/{len(train_loader)}] '
                      f'd_loss: {d_loss.item():.4f} g_loss: {g_loss.item():.4f}')
                
                # Clear some memory
                del d_loss, g_loss, fake_images, real_images
                torch.cuda.empty_cache()
        
        # Average losses for the epoch
        d_losses.append(epoch_d_loss / len(train_loader))
        g_losses.append(epoch_g_loss / len(train_loader))
        
        # Step the schedulers
        g_scheduler.step()
        d_scheduler.step()
        
        # Save checkpoint with memory optimization
        if (epoch + 1) % 10 == 0:
            torch.save({
                'epoch': epoch,
                'generator_state_dict': generator.state_dict(),
                'discriminator_state_dict': discriminator.state_dict(),
                'g_optimizer_state_dict': g_optimizer.state_dict(),
                'd_optimizer_state_dict': d_optimizer.state_dict(),
            }, f'stylegan_checkpoint_epoch_{epoch+1}.pth')
    
    # Plot the loss curves
    plt.figure(figsize=(10, 5))
    plt.plot(d_losses, label='Discriminator Loss')
    plt.plot(g_losses, label='Generator Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Training Loss Curve')
    plt.show()

# %%
def explore_latent_space(generator, n_samples=5, save_dir='generated_faces'):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    generator.eval()
    
    os.makedirs(save_dir, exist_ok=True)
    
    with torch.no_grad():
        z1 = torch.randn(1, 512).to(device)
        z2 = torch.randn(1, 512).to(device)
        
        for i in range(n_samples):
            # Generate one image at a time to save memory
            alpha = i / (n_samples - 1)
            z = z1 * (1 - alpha) + z2 * alpha
            
            fake_image = generator(z)
            fake_image = (fake_image + 1) / 2
            fake_image = fake_image.cpu().squeeze(0)
            
            transforms.ToPILImage()(fake_image).save(
                os.path.join(save_dir, f'interpolation_{i}.jpg')
            )
            
            # Clear memory
            del fake_image
            torch.cuda.empty_cache()

# %%
if __name__ == "__main__":
    # Set memory optimization flags
    torch.backends.cudnn.benchmark = True
    torch.backends.cuda.matmul.allow_tf32 = True
    torch.backends.cudnn.allow_tf32 = True
    
    train_dir = "/kaggle/input/stylegan/STYLEGAN/train"
    test_dir = "/kaggle/input/stylegan/STYLEGAN/test"
    
    # Train with reduced batch size and image size
    train_stylegan(train_dir, test_dir, batch_size=8)
# Out:
# /tmp/ipykernel_24/3939366788.py:18: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# /tmp/ipykernel_24/3939366788.py:44: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# /tmp/ipykernel_24/3939366788.py:64: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch [0/200] Batch [0/1249] d_loss: 1.3863 g_loss: 0.6897
# Epoch [0/200] Batch [50/1249] d_loss: 0.8215 g_loss: 4.7710
# Epoch [0/200] Batch [100/1249] d_loss: 0.3253 g_loss: 4.0048
# Epoch [0/200] Batch [150/1249] d_loss: 0.3181 g_loss: 6.6815
# Epoch [0/200] Batch [200/1249] d_loss: 0.1217 g_loss: 6.8133
# Epoch [0/200] Batch [250/1249] d_loss: 0.1141 g_loss: 8.2058
# Epoch [0/200] Batch [300/1249] d_loss: 0.0785 g_loss: 5.8701
# Epoch [0/200] Batch [350/1249] d_loss: 0.6147 g_loss: 6.7424
# Epoch [0/200] Batch [400/1249] d_loss: 0.0802 g_loss: 6.8988
# Epoch [0/200] Batch [450/1249] d_loss: 0.1963 g_loss: 5.9871
# Epoch [0/200] Batch [500/1249] d_loss: 0.0445 g_loss: 5.8077
# Epoch [0/200] Batch [550/1249] d_loss: 0.2570 g_loss: 6.3585
# Epoch [0/200] Batch [600/1249] d_loss: 0.0104 g_loss: 7.0446
# Epoch [0/200] Batch [650/1249] d_loss: 0.0890 g_loss: 5.4293
# Epoch [0/200] Batch [700/1249] d_loss: 0.0505 g_loss: 5.4727
# Epoch [0/200] Batch [750/1249] d_loss: 0.0290 g_loss: 8.3341
# Epoch [0/200] Batch [800/1249] d_loss: 0.0155 g_loss: 6.5181
# Epoch [0/200] Batch [850/1249] d_loss: 0.0096 g_loss: 6.9879
# Epoch [0/200] Batch [900/1249] d_loss: 0.0016 g_loss: 9.0649
# Epoch [0/200] Batch [950/1249] d_loss: 0.0037 g_loss: 7.0673
# Epoch [0/200] Batch [1000/1249] d_loss: 0.0255 g_loss: 5.4288
# Epoch [0/200] Batch [1050/1249] d_loss: 0.0087 g_loss: 9.6677
# Epoch [0/200] Batch [1100/1249] d_loss: 0.3009 g_loss: 4.4890
# Epoch [0/200] Batch [1150/1249] d_loss: 0.2467 g_loss: 10.3273
# Epoch [0/200] Batch [1200/1249] d_loss: 0.0088 g_loss: 7.3732
# Epoch [1/200] Batch [0/1249] d_loss: 0.0014 g_loss: 9.2420
# Epoch [1/200] Batch [50/1249] d_loss: 0.0037 g_loss: 8.0224
# Epoch [1/200] Batch [100/1249] d_loss: 0.0010 g_loss: 8.4339
# Epoch [1/200] Batch [150/1249] d_loss: 0.0008 g_loss: 9.1541
# Epoch [1/200] Batch [200/1249] d_loss: 0.2394 g_loss: 7.3478
# Epoch [1/200] Batch [250/1249] d_loss: 0.0083 g_loss: 8.6609
# Epoch [1/200] Batch [300/1249] d_loss: 0.0058 g_loss: 9.5330
# Epoch [1/200] Batch [350/1249] d_loss: 0.0291 g_loss: 9.2362
# Epoch [1/200] Batch [400/1249] d_loss: 0.0001 g_loss: 10.7149
# Epoch [1/200] Batch [450/1249] d_loss: 0.0253 g_loss: 8.3588
# Epoch [1/200] Batch [500/1249] d_loss: 0.0004 g_loss: 8.7991
# Epoch [1/200] Batch [550/1249] d_loss: 0.0007 g_loss: 9.0678
# Epoch [1/200] Batch [600/1249] d_loss: 0.0013 g_loss: 10.1364
# Epoch [1/200] Batch [650/1249] d_loss: 0.0021 g_loss: 8.1698
# Epoch [1/200] Batch [700/1249] d_loss: 0.0004 g_loss: 10.1897
# Epoch [1/200] Batch [750/1249] d_loss: 0.0003 g_loss: 14.6060
# Epoch [1/200] Batch [800/1249] d_loss: 0.0004 g_loss: 8.6752
# Epoch [1/200] Batch [850/1249] d_loss: 0.0002 g_loss: 9.7238
# Epoch [1/200] Batch [900/1249] d_loss: 0.0047 g_loss: 9.5222
# Epoch [1/200] Batch [950/1249] d_loss: 0.0036 g_loss: 9.9332
# Epoch [1/200] Batch [1000/1249] d_loss: 0.0008 g_loss: 10.0470
# Epoch [1/200] Batch [1050/1249] d_loss: 0.0001 g_loss: 11.0528
# Epoch [1/200] Batch [1100/1249] d_loss: 0.0031 g_loss: 10.9269
# Epoch [1/200] Batch [1150/1249] d_loss: 0.0010 g_loss: 11.5123
# Epoch [1/200] Batch [1200/1249] d_loss: 0.0011 g_loss: 10.8206
# Epoch [2/200] Batch [0/1249] d_loss: 0.1678 g_loss: 3.7255
# Epoch [2/200] Batch [50/1249] d_loss: 0.0001 g_loss: 13.7920
# Epoch [2/200] Batch [100/1249] d_loss: 0.0014 g_loss: 11.8709
# Epoch [2/200] Batch [150/1249] d_loss: 0.0001 g_loss: 13.0069
# Epoch [2/200] Batch [200/1249] d_loss: 0.0030 g_loss: 11.0880
# Epoch [2/200] Batch [250/1249] d_loss: 0.0003 g_loss: 12.9199
# Epoch [2/200] Batch [300/1249] d_loss: 0.0050 g_loss: 7.0509
# Epoch [2/200] Batch [350/1249] d_loss: 0.0002 g_loss: 11.9440
# Epoch [2/200] Batch [400/1249] d_loss: 0.0234 g_loss: 10.7474
# Epoch [2/200] Batch [450/1249] d_loss: 0.0076 g_loss: 8.9951
# Epoch [2/200] Batch [500/1249] d_loss: 0.0015 g_loss: 9.7519
# Epoch [2/200] Batch [550/1249] d_loss: 0.0025 g_loss: 8.6409
# Epoch [2/200] Batch [600/1249] d_loss: 0.0354 g_loss: 9.8044
# Epoch [2/200] Batch [650/1249] d_loss: 0.0069 g_loss: 9.3884
# Epoch [2/200] Batch [700/1249] d_loss: 0.0313 g_loss: 9.1435
# Epoch [2/200] Batch [750/1249] d_loss: 0.6735 g_loss: 4.0590
# Epoch [2/200] Batch [800/1249] d_loss: 0.0297 g_loss: 6.2881
# Epoch [2/200] Batch [850/1249] d_loss: 0.0480 g_loss: 7.1439
# Epoch [2/200] Batch [900/1249] d_loss: 0.5209 g_loss: 5.0920
# Epoch [2/200] Batch [950/1249] d_loss: 0.3310 g_loss: 7.0733
# Epoch [2/200] Batch [1000/1249] d_loss: 0.0346 g_loss: 8.3560
# Epoch [2/200] Batch [1050/1249] d_loss: 0.0875 g_loss: 6.0457
# Epoch [2/200] Batch [1100/1249] d_loss: 0.4529 g_loss: 3.0604
# Epoch [2/200] Batch [1150/1249] d_loss: 0.2200 g_loss: 3.9335
# Epoch [2/200] Batch [1200/1249] d_loss: 0.3630 g_loss: 3.6391
# Epoch [3/200] Batch [0/1249] d_loss: 0.2577 g_loss: 3.5088
# Epoch [3/200] Batch [50/1249] d_loss: 0.2944 g_loss: 3.4663
# Epoch [3/200] Batch [100/1249] d_loss: 0.6644 g_loss: 3.4559
# Epoch [3/200] Batch [150/1249] d_loss: 0.7100 g_loss: 2.4595
# Epoch [3/200] Batch [200/1249] d_loss: 0.9327 g_loss: 2.9443
# Epoch [3/200] Batch [250/1249] d_loss: 0.5330 g_loss: 2.9528
# Epoch [3/200] Batch [300/1249] d_loss: 1.0501 g_loss: 1.3690
# Epoch [3/200] Batch [350/1249] d_loss: 0.9836 g_loss: 0.9684
# Epoch [3/200] Batch [400/1249] d_loss: 1.1345 g_loss: 1.8032
# Epoch [3/200] Batch [450/1249] d_loss: 0.9531 g_loss: 2.3280
# Epoch [3/200] Batch [500/1249] d_loss: 1.0225 g_loss: 2.0578
# Epoch [3/200] Batch [550/1249] d_loss: 1.0144 g_loss: 0.9450
# Epoch [3/200] Batch [600/1249] d_loss: 1.3122 g_loss: 1.1491
# Epoch [3/200] Batch [650/1249] d_loss: 1.3485 g_loss: 0.8610
# Epoch [3/200] Batch [700/1249] d_loss: 0.8895 g_loss: 1.7860
# Epoch [3/200] Batch [750/1249] d_loss: 1.1276 g_loss: 1.1859
# Epoch [3/200] Batch [800/1249] d_loss: 1.1377 g_loss: 1.0789
# Epoch [3/200] Batch [850/1249] d_loss: 1.0722 g_loss: 1.3839
# Epoch [3/200] Batch [900/1249] d_loss: 1.2228 g_loss: 1.1897
# Epoch [3/200] Batch [950/1249] d_loss: 1.0701 g_loss: 0.6308
# Epoch [3/200] Batch [1000/1249] d_loss: 1.1358 g_loss: 1.0784
# Epoch [3/200] Batch [1050/1249] d_loss: 1.3174 g_loss: 0.8364
# Epoch [3/200] Batch [1100/1249] d_loss: 1.0590 g_loss: 0.7065
# Epoch [3/200] Batch [1150/1249] d_loss: 1.1619 g_loss: 1.3721
# Epoch [3/200] Batch [1200/1249] d_loss: 1.0813 g_loss: 1.0927
# Epoch [4/200] Batch [0/1249] d_loss: 1.2663 g_loss: 0.6494
# Epoch [4/200] Batch [50/1249] d_loss: 1.3417 g_loss: 1.2560
# Epoch [4/200] Batch [100/1249] d_loss: 1.3573 g_loss: 0.8342
# Epoch [4/200] Batch [150/1249] d_loss: 1.1752 g_loss: 1.1942
# Epoch [4/200] Batch [200/1249] d_loss: 1.3569 g_loss: 1.1182
# Epoch [4/200] Batch [250/1249] d_loss: 1.3900 g_loss: 0.8268
# Epoch [4/200] Batch [300/1249] d_loss: 1.3069 g_loss: 0.9801
# Epoch [4/200] Batch [350/1249] d_loss: 1.3833 g_loss: 1.1246
# Epoch [4/200] Batch [400/1249] d_loss: 1.4394 g_loss: 1.4469
# Epoch [4/200] Batch [450/1249] d_loss: 1.1717 g_loss: 1.3260
# Epoch [4/200] Batch [500/1249] d_loss: 1.2512 g_loss: 0.6162
# Epoch [4/200] Batch [550/1249] d_loss: 1.3266 g_loss: 0.5052
# Epoch [4/200] Batch [600/1249] d_loss: 1.2548 g_loss: 1.0270
# Epoch [4/200] Batch [650/1249] d_loss: 1.2217 g_loss: 0.8604
# Epoch [4/200] Batch [700/1249] d_loss: 1.4625 g_loss: 0.7183
# Epoch [4/200] Batch [750/1249] d_loss: 1.2867 g_loss: 0.8342
# Epoch [4/200] Batch [800/1249] d_loss: 1.4494 g_loss: 0.7656
# Epoch [4/200] Batch [850/1249] d_loss: 1.3763 g_loss: 0.7415
# Epoch [4/200] Batch [900/1249] d_loss: 1.4720 g_loss: 0.7864
# Epoch [4/200] Batch [950/1249] d_loss: 1.3044 g_loss: 1.0770
# Epoch [4/200] Batch [1000/1249] d_loss: 1.3141 g_loss: 0.7178
# Epoch [4/200] Batch [1050/1249] d_loss: 1.2232 g_loss: 1.2183
# Epoch [4/200] Batch [1100/1249] d_loss: 1.2867 g_loss: 0.8419
# Epoch [4/200] Batch [1150/1249] d_loss: 1.3577 g_loss: 0.6155
# Epoch [4/200] Batch [1200/1249] d_loss: 1.3642 g_loss: 0.8814
# Epoch [5/200] Batch [0/1249] d_loss: 1.3976 g_loss: 0.7862
# Epoch [5/200] Batch [50/1249] d_loss: 1.4149 g_loss: 0.8931
# Epoch [5/200] Batch [100/1249] d_loss: 1.4008 g_loss: 0.5767
# Epoch [5/200] Batch [150/1249] d_loss: 1.4142 g_loss: 0.7148
# Epoch [5/200] Batch [200/1249] d_loss: 1.4184 g_loss: 0.7876
# Epoch [5/200] Batch [250/1249] d_loss: 1.4278 g_loss: 0.6798
# Epoch [5/200] Batch [300/1249] d_loss: 1.3759 g_loss: 0.7420
# Epoch [5/200] Batch [350/1249] d_loss: 1.3712 g_loss: 0.7496
# Epoch [5/200] Batch [400/1249] d_loss: 1.4063 g_loss: 0.7405
# Epoch [5/200] Batch [450/1249] d_loss: 1.4381 g_loss: 0.6325
# Epoch [5/200] Batch [500/1249] d_loss: 1.3811 g_loss: 0.8985
# Epoch [5/200] Batch [550/1249] d_loss: 1.3097 g_loss: 0.8767
# Epoch [5/200] Batch [600/1249] d_loss: 1.4298 g_loss: 0.7469
# Epoch [5/200] Batch [650/1249] d_loss: 1.3568 g_loss: 0.7788
# Epoch [5/200] Batch [700/1249] d_loss: 1.3591 g_loss: 0.8840
# Epoch [5/200] Batch [750/1249] d_loss: 1.3682 g_loss: 0.7978
# Epoch [5/200] Batch [800/1249] d_loss: 1.4351 g_loss: 0.7874
# Epoch [5/200] Batch [850/1249] d_loss: 1.3924 g_loss: 0.8303
# Epoch [5/200] Batch [900/1249] d_loss: 1.4444 g_loss: 0.9463
# Epoch [5/200] Batch [950/1249] d_loss: 1.3395 g_loss: 0.7190
# Epoch [5/200] Batch [1000/1249] d_loss: 1.3705 g_loss: 0.9217
# Epoch [5/200] Batch [1050/1249] d_loss: 1.4331 g_loss: 0.5513
# Epoch [5/200] Batch [1100/1249] d_loss: 1.3614 g_loss: 0.6673
# Epoch [5/200] Batch [1150/1249] d_loss: 1.3786 g_loss: 0.8794
# Epoch [5/200] Batch [1200/1249] d_loss: 1.3282 g_loss: 0.7459
# Epoch [6/200] Batch [0/1249] d_loss: 1.3496 g_loss: 0.7991
# Epoch [6/200] Batch [50/1249] d_loss: 1.4202 g_loss: 0.8865
# Epoch [6/200] Batch [100/1249] d_loss: 1.3407 g_loss: 0.9062
# Epoch [6/200] Batch [150/1249] d_loss: 1.3737 g_loss: 0.8310
# Epoch [6/200] Batch [200/1249] d_loss: 1.4519 g_loss: 0.8489
# Epoch [6/200] Batch [250/1249] d_loss: 1.3996 g_loss: 0.6512
# Epoch [6/200] Batch [300/1249] d_loss: 1.3855 g_loss: 0.5524
# Epoch [6/200] Batch [350/1249] d_loss: 1.3635 g_loss: 0.6497
# Epoch [6/200] Batch [400/1249] d_loss: 1.4062 g_loss: 0.6830
# Epoch [6/200] Batch [450/1249] d_loss: 1.3834 g_loss: 0.7169
# Epoch [6/200] Batch [500/1249] d_loss: 1.3636 g_loss: 0.7814
# Epoch [6/200] Batch [550/1249] d_loss: 1.3549 g_loss: 0.6455
# Epoch [6/200] Batch [600/1249] d_loss: 1.3711 g_loss: 0.7302
# Epoch [6/200] Batch [650/1249] d_loss: 1.3709 g_loss: 0.6732
# Epoch [6/200] Batch [700/1249] d_loss: 1.3469 g_loss: 0.7915
# Epoch [6/200] Batch [750/1249] d_loss: 1.3602 g_loss: 0.6694
# Epoch [6/200] Batch [800/1249] d_loss: 1.3622 g_loss: 0.6984
# Epoch [6/200] Batch [850/1249] d_loss: 1.3289 g_loss: 0.7852
# Epoch [6/200] Batch [900/1249] d_loss: 1.3756 g_loss: 0.8676
# Epoch [6/200] Batch [950/1249] d_loss: 1.3365 g_loss: 0.8597
# Epoch [6/200] Batch [1000/1249] d_loss: 1.3818 g_loss: 0.8250
# Epoch [6/200] Batch [1050/1249] d_loss: 1.3359 g_loss: 0.7837
# Epoch [6/200] Batch [1100/1249] d_loss: 1.3422 g_loss: 0.7361
# Epoch [6/200] Batch [1150/1249] d_loss: 1.3769 g_loss: 0.9306
# Epoch [6/200] Batch [1200/1249] d_loss: 1.3289 g_loss: 0.8470
# Epoch [7/200] Batch [0/1249] d_loss: 1.3099 g_loss: 0.9498
# Epoch [7/200] Batch [50/1249] d_loss: 1.3277 g_loss: 0.8274
# Epoch [7/200] Batch [100/1249] d_loss: 1.3653 g_loss: 0.7301
# Epoch [7/200] Batch [150/1249] d_loss: 1.4172 g_loss: 0.8294
# Epoch [7/200] Batch [200/1249] d_loss: 1.3755 g_loss: 0.8088
# Epoch [7/200] Batch [250/1249] d_loss: 1.3771 g_loss: 0.7054
# Epoch [7/200] Batch [300/1249] d_loss: 1.4012 g_loss: 0.7101
# Epoch [7/200] Batch [350/1249] d_loss: 1.3770 g_loss: 1.0968
# Epoch [7/200] Batch [400/1249] d_loss: 1.3937 g_loss: 0.6768
# Epoch [7/200] Batch [450/1249] d_loss: 1.3913 g_loss: 0.7870
# Epoch [7/200] Batch [500/1249] d_loss: 1.2775 g_loss: 0.8251
# Epoch [7/200] Batch [550/1249] d_loss: 1.3605 g_loss: 0.6740
# Epoch [7/200] Batch [600/1249] d_loss: 1.3857 g_loss: 0.6768
# Epoch [7/200] Batch [650/1249] d_loss: 1.3416 g_loss: 0.7267
# Epoch [7/200] Batch [700/1249] d_loss: 1.2982 g_loss: 0.8994
# Epoch [7/200] Batch [750/1249] d_loss: 1.3547 g_loss: 0.5579
# Epoch [7/200] Batch [800/1249] d_loss: 1.4252 g_loss: 0.9822
# Epoch [7/200] Batch [850/1249] d_loss: 1.3273 g_loss: 0.7959
# Epoch [7/200] Batch [900/1249] d_loss: 1.3430 g_loss: 0.7522
# Epoch [7/200] Batch [950/1249] d_loss: 1.3602 g_loss: 0.4933
# Epoch [7/200] Batch [1000/1249] d_loss: 1.4198 g_loss: 0.4876
# Epoch [7/200] Batch [1050/1249] d_loss: 1.5270 g_loss: 0.8764
# Epoch [7/200] Batch [1100/1249] d_loss: 1.2743 g_loss: 0.8514
# Epoch [7/200] Batch [1150/1249] d_loss: 1.2674 g_loss: 0.8507
# Epoch [7/200] Batch [1200/1249] d_loss: 1.2476 g_loss: 1.0141
# Epoch [8/200] Batch [0/1249] d_loss: 1.2663 g_loss: 0.9278
# Epoch [8/200] Batch [50/1249] d_loss: 1.3147 g_loss: 0.9177
# Epoch [8/200] Batch [100/1249] d_loss: 1.3364 g_loss: 0.8224
# Epoch [8/200] Batch [150/1249] d_loss: 1.3548 g_loss: 0.9403
# Epoch [8/200] Batch [200/1249] d_loss: 1.2412 g_loss: 0.8401
# Epoch [8/200] Batch [250/1249] d_loss: 1.3623 g_loss: 0.6450
# Epoch [8/200] Batch [300/1249] d_loss: 1.3951 g_loss: 0.5998
# Epoch [8/200] Batch [350/1249] d_loss: 1.3462 g_loss: 1.0722
# Epoch [8/200] Batch [400/1249] d_loss: 1.3064 g_loss: 0.8739
# Epoch [8/200] Batch [450/1249] d_loss: 1.3434 g_loss: 1.0586
# Epoch [8/200] Batch [500/1249] d_loss: 1.4170 g_loss: 0.8899
# Epoch [8/200] Batch [550/1249] d_loss: 1.2927 g_loss: 1.0013
# Epoch [8/200] Batch [600/1249] d_loss: 1.2531 g_loss: 0.8868
# Epoch [8/200] Batch [650/1249] d_loss: 1.2604 g_loss: 0.8543
# Epoch [8/200] Batch [700/1249] d_loss: 1.3568 g_loss: 0.4935
# Epoch [8/200] Batch [750/1249] d_loss: 1.3089 g_loss: 1.0466
# Epoch [8/200] Batch [800/1249] d_loss: 1.3113 g_loss: 0.6544
# Epoch [8/200] Batch [850/1249] d_loss: 1.3054 g_loss: 0.7305
# Epoch [8/200] Batch [900/1249] d_loss: 1.2774 g_loss: 0.7655
# Epoch [8/200] Batch [950/1249] d_loss: 1.2311 g_loss: 1.0452
# Epoch [8/200] Batch [1000/1249] d_loss: 1.2397 g_loss: 0.7425
# Epoch [8/200] Batch [1050/1249] d_loss: 1.3175 g_loss: 1.1338
# Epoch [8/200] Batch [1100/1249] d_loss: 1.4802 g_loss: 0.4821
# Epoch [8/200] Batch [1150/1249] d_loss: 1.2610 g_loss: 0.9277
# Epoch [8/200] Batch [1200/1249] d_loss: 1.3003 g_loss: 0.7630
# Epoch [9/200] Batch [0/1249] d_loss: 1.2808 g_loss: 0.8577
# Epoch [9/200] Batch [50/1249] d_loss: 1.3654 g_loss: 0.9389
# Epoch [9/200] Batch [100/1249] d_loss: 1.3025 g_loss: 0.8843
# Epoch [9/200] Batch [150/1249] d_loss: 1.1644 g_loss: 0.8419
# Epoch [9/200] Batch [200/1249] d_loss: 1.3789 g_loss: 1.1093
# Epoch [9/200] Batch [250/1249] d_loss: 1.4004 g_loss: 0.6747
# Epoch [9/200] Batch [300/1249] d_loss: 1.2697 g_loss: 0.7751
# Epoch [9/200] Batch [350/1249] d_loss: 1.3565 g_loss: 0.8852
# Epoch [9/200] Batch [400/1249] d_loss: 1.3319 g_loss: 0.7035
# Epoch [9/200] Batch [450/1249] d_loss: 1.4109 g_loss: 0.6031
# Epoch [9/200] Batch [500/1249] d_loss: 1.2833 g_loss: 0.7740
# Epoch [9/200] Batch [550/1249] d_loss: 1.4248 g_loss: 1.0839
# Epoch [9/200] Batch [600/1249] d_loss: 1.3842 g_loss: 0.9440
# Epoch [9/200] Batch [650/1249] d_loss: 1.4175 g_loss: 0.7168
# Epoch [9/200] Batch [700/1249] d_loss: 1.3837 g_loss: 0.8032
# Epoch [9/200] Batch [750/1249] d_loss: 1.3136 g_loss: 0.7447
# Epoch [9/200] Batch [800/1249] d_loss: 1.3029 g_loss: 0.4659
# Epoch [9/200] Batch [850/1249] d_loss: 1.3713 g_loss: 0.7902
# Epoch [9/200] Batch [900/1249] d_loss: 1.2868 g_loss: 0.8763
# Epoch [9/200] Batch [950/1249] d_loss: 1.1766 g_loss: 1.1612
# Epoch [9/200] Batch [1000/1249] d_loss: 1.3001 g_loss: 0.8541
# Epoch [9/200] Batch [1050/1249] d_loss: 1.4510 g_loss: 0.3852
# Epoch [9/200] Batch [1100/1249] d_loss: 1.3402 g_loss: 0.6673
# Epoch [9/200] Batch [1150/1249] d_loss: 1.4215 g_loss: 0.5813
# Epoch [9/200] Batch [1200/1249] d_loss: 1.2735 g_loss: 0.8131
# Epoch [10/200] Batch [0/1249] d_loss: 1.2893 g_loss: 0.8501
# Epoch [10/200] Batch [50/1249] d_loss: 1.3033 g_loss: 0.7121
# Epoch [10/200] Batch [100/1249] d_loss: 1.2850 g_loss: 0.6944
# Epoch [10/200] Batch [150/1249] d_loss: 1.3755 g_loss: 0.8110
# Epoch [10/200] Batch [200/1249] d_loss: 1.3251 g_loss: 0.8023
# Epoch [10/200] Batch [250/1249] d_loss: 1.2567 g_loss: 0.9593
# Epoch [10/200] Batch [300/1249] d_loss: 1.3107 g_loss: 0.8099
# Epoch [10/200] Batch [350/1249] d_loss: 1.3678 g_loss: 0.5874
# Epoch [10/200] Batch [400/1249] d_loss: 1.1900 g_loss: 0.7585
# Epoch [10/200] Batch [450/1249] d_loss: 1.3330 g_loss: 0.9143
# Epoch [10/200] Batch [500/1249] d_loss: 1.2736 g_loss: 0.9974
# Epoch [10/200] Batch [550/1249] d_loss: 1.3498 g_loss: 1.0313
# Epoch [10/200] Batch [600/1249] d_loss: 1.2469 g_loss: 0.8744
# Epoch [10/200] Batch [650/1249] d_loss: 1.2475 g_loss: 0.7072
# Epoch [10/200] Batch [700/1249] d_loss: 1.3492 g_loss: 0.8244
# Epoch [10/200] Batch [750/1249] d_loss: 1.2851 g_loss: 0.7421
# Epoch [10/200] Batch [800/1249] d_loss: 1.2604 g_loss: 0.8723
# Epoch [10/200] Batch [850/1249] d_loss: 1.4457 g_loss: 0.8836
# Epoch [10/200] Batch [900/1249] d_loss: 1.3281 g_loss: 1.0935
# Epoch [10/200] Batch [950/1249] d_loss: 1.2768 g_loss: 0.8720
# Epoch [10/200] Batch [1000/1249] d_loss: 1.2930 g_loss: 0.5498
# Epoch [10/200] Batch [1050/1249] d_loss: 1.3338 g_loss: 0.8727
# Epoch [10/200] Batch [1100/1249] d_loss: 1.3081 g_loss: 0.6994
# Epoch [10/200] Batch [1150/1249] d_loss: 1.3251 g_loss: 0.7465
# Epoch [10/200] Batch [1200/1249] d_loss: 1.3703 g_loss: 0.9753
# Epoch [11/200] Batch [0/1249] d_loss: 1.3269 g_loss: 0.9808
# Epoch [11/200] Batch [50/1249] d_loss: 1.3310 g_loss: 0.8954
# Epoch [11/200] Batch [100/1249] d_loss: 1.2978 g_loss: 0.7675
# Epoch [11/200] Batch [150/1249] d_loss: 1.2750 g_loss: 1.1861
# Epoch [11/200] Batch [200/1249] d_loss: 1.3514 g_loss: 0.9800
# Epoch [11/200] Batch [250/1249] d_loss: 1.3813 g_loss: 0.4470
# Epoch [11/200] Batch [300/1249] d_loss: 1.3255 g_loss: 1.1055
# Epoch [11/200] Batch [350/1249] d_loss: 1.3744 g_loss: 0.7084
# Epoch [11/200] Batch [400/1249] d_loss: 1.2447 g_loss: 0.8759
# Epoch [11/200] Batch [450/1249] d_loss: 1.2748 g_loss: 1.1061
# Epoch [11/200] Batch [500/1249] d_loss: 1.3117 g_loss: 0.7324
# Epoch [11/200] Batch [550/1249] d_loss: 1.3473 g_loss: 1.0792
# Epoch [11/200] Batch [600/1249] d_loss: 1.3434 g_loss: 0.5538
# Epoch [11/200] Batch [650/1249] d_loss: 1.2782 g_loss: 0.7924
# Epoch [11/200] Batch [700/1249] d_loss: 1.1972 g_loss: 0.9973
# Epoch [11/200] Batch [750/1249] d_loss: 1.2470 g_loss: 1.0259
# Epoch [11/200] Batch [800/1249] d_loss: 1.3218 g_loss: 1.3727
# Epoch [11/200] Batch [850/1249] d_loss: 1.1985 g_loss: 1.0390
# Epoch [11/200] Batch [900/1249] d_loss: 1.3307 g_loss: 0.6188
# Epoch [11/200] Batch [950/1249] d_loss: 1.2644 g_loss: 0.6545
# Epoch [11/200] Batch [1000/1249] d_loss: 1.2944 g_loss: 0.9316
# Epoch [11/200] Batch [1050/1249] d_loss: 1.2290 g_loss: 1.0267
# Epoch [11/200] Batch [1100/1249] d_loss: 1.2250 g_loss: 1.0198
# Epoch [11/200] Batch [1150/1249] d_loss: 1.1938 g_loss: 0.9806
# Epoch [11/200] Batch [1200/1249] d_loss: 1.2248 g_loss: 0.7975
# Epoch [12/200] Batch [0/1249] d_loss: 1.2630 g_loss: 0.6750
# Epoch [12/200] Batch [50/1249] d_loss: 1.4934 g_loss: 0.9668
# Epoch [12/200] Batch [100/1249] d_loss: 1.2816 g_loss: 0.7556
# Epoch [12/200] Batch [150/1249] d_loss: 1.1801 g_loss: 0.9590
# Epoch [12/200] Batch [200/1249] d_loss: 1.2059 g_loss: 0.8907
# Epoch [12/200] Batch [250/1249] d_loss: 1.3172 g_loss: 0.8676
# Epoch [12/200] Batch [300/1249] d_loss: 1.2870 g_loss: 0.9293
# Epoch [12/200] Batch [350/1249] d_loss: 1.2806 g_loss: 1.0488
# Epoch [12/200] Batch [400/1249] d_loss: 1.2081 g_loss: 0.4650
# Epoch [12/200] Batch [450/1249] d_loss: 1.4687 g_loss: 1.1378
# Epoch [12/200] Batch [500/1249] d_loss: 1.2064 g_loss: 0.8532
# Epoch [12/200] Batch [550/1249] d_loss: 1.1656 g_loss: 1.1266
# Epoch [12/200] Batch [600/1249] d_loss: 1.2940 g_loss: 0.5310
# Epoch [12/200] Batch [650/1249] d_loss: 1.2844 g_loss: 0.9349
# Epoch [12/200] Batch [700/1249] d_loss: 1.4149 g_loss: 1.1825
# Epoch [12/200] Batch [750/1249] d_loss: 1.3262 g_loss: 1.1338
# Epoch [12/200] Batch [800/1249] d_loss: 1.1679 g_loss: 0.9713
# Epoch [12/200] Batch [850/1249] d_loss: 1.3671 g_loss: 1.1592
# Epoch [12/200] Batch [900/1249] d_loss: 1.3491 g_loss: 0.8726
# Epoch [12/200] Batch [950/1249] d_loss: 1.3155 g_loss: 0.8590
# Epoch [12/200] Batch [1000/1249] d_loss: 1.4534 g_loss: 0.4775
# Epoch [12/200] Batch [1050/1249] d_loss: 1.2092 g_loss: 0.9488
# Epoch [12/200] Batch [1100/1249] d_loss: 1.2730 g_loss: 0.9517
# Epoch [12/200] Batch [1150/1249] d_loss: 1.2415 g_loss: 1.0579
# Epoch [12/200] Batch [1200/1249] d_loss: 1.5651 g_loss: 1.2535
# Epoch [13/200] Batch [0/1249] d_loss: 1.2223 g_loss: 1.0451
# Epoch [13/200] Batch [50/1249] d_loss: 1.4138 g_loss: 1.3191
# Epoch [13/200] Batch [100/1249] d_loss: 1.1074 g_loss: 1.2780
# Epoch [13/200] Batch [150/1249] d_loss: 1.0469 g_loss: 1.0059
# Epoch [13/200] Batch [200/1249] d_loss: 1.2310 g_loss: 0.7797
# Epoch [13/200] Batch [250/1249] d_loss: 1.2210 g_loss: 0.8398
# Epoch [13/200] Batch [300/1249] d_loss: 1.1922 g_loss: 0.8741
# Epoch [13/200] Batch [350/1249] d_loss: 1.2541 g_loss: 0.9978
# Epoch [13/200] Batch [400/1249] d_loss: 1.2942 g_loss: 0.8395
# Epoch [13/200] Batch [450/1249] d_loss: 1.1156 g_loss: 1.2944
# Epoch [13/200] Batch [500/1249] d_loss: 1.1312 g_loss: 1.1742
# Epoch [13/200] Batch [550/1249] d_loss: 1.2297 g_loss: 0.7101
# Epoch [13/200] Batch [600/1249] d_loss: 1.1562 g_loss: 0.9077
# Epoch [13/200] Batch [650/1249] d_loss: 1.2635 g_loss: 0.6453
# Epoch [13/200] Batch [700/1249] d_loss: 1.1741 g_loss: 0.8782
# Epoch [13/200] Batch [750/1249] d_loss: 1.2102 g_loss: 1.1130
# Epoch [13/200] Batch [800/1249] d_loss: 1.3927 g_loss: 1.3658
# Epoch [13/200] Batch [850/1249] d_loss: 1.3006 g_loss: 0.6283
# Epoch [13/200] Batch [900/1249] d_loss: 1.1767 g_loss: 1.2417
# Epoch [13/200] Batch [950/1249] d_loss: 1.1783 g_loss: 1.1447
# Epoch [13/200] Batch [1000/1249] d_loss: 1.3621 g_loss: 0.5624
# Epoch [13/200] Batch [1050/1249] d_loss: 1.2699 g_loss: 0.9652
# Epoch [13/200] Batch [1100/1249] d_loss: 1.2080 g_loss: 0.8416
# Epoch [13/200] Batch [1150/1249] d_loss: 1.3031 g_loss: 0.9400
# Epoch [13/200] Batch [1200/1249] d_loss: 1.2841 g_loss: 0.6235
# Epoch [14/200] Batch [0/1249] d_loss: 1.0413 g_loss: 1.4606
# Epoch [14/200] Batch [50/1249] d_loss: 1.2881 g_loss: 0.9145
# Epoch [14/200] Batch [100/1249] d_loss: 1.2407 g_loss: 0.8268
# Epoch [14/200] Batch [150/1249] d_loss: 1.2363 g_loss: 1.1328
# Epoch [14/200] Batch [200/1249] d_loss: 1.2123 g_loss: 1.1265
# Epoch [14/200] Batch [250/1249] d_loss: 1.2296 g_loss: 0.8197
# Epoch [14/200] Batch [300/1249] d_loss: 1.2728 g_loss: 0.6211
# Epoch [14/200] Batch [350/1249] d_loss: 1.1641 g_loss: 0.7924
# Epoch [14/200] Batch [400/1249] d_loss: 1.2527 g_loss: 0.9024
# Epoch [14/200] Batch [450/1249] d_loss: 1.4309 g_loss: 0.9305
# Epoch [14/200] Batch [500/1249] d_loss: 1.2376 g_loss: 0.9596
# Epoch [14/200] Batch [550/1249] d_loss: 1.2795 g_loss: 0.7105
# Epoch [14/200] Batch [600/1249] d_loss: 1.1145 g_loss: 0.9691
# Epoch [14/200] Batch [650/1249] d_loss: 1.3185 g_loss: 0.7553
# Epoch [14/200] Batch [700/1249] d_loss: 1.4306 g_loss: 1.0583
# Epoch [14/200] Batch [750/1249] d_loss: 1.4354 g_loss: 1.3595
# Epoch [14/200] Batch [800/1249] d_loss: 1.3413 g_loss: 1.1416
# Epoch [14/200] Batch [850/1249] d_loss: 1.2825 g_loss: 0.8525
# Epoch [14/200] Batch [900/1249] d_loss: 1.5837 g_loss: 1.1795
# Epoch [14/200] Batch [950/1249] d_loss: 1.2892 g_loss: 0.6128
# Epoch [14/200] Batch [1000/1249] d_loss: 1.0690 g_loss: 0.8672
# Epoch [14/200] Batch [1050/1249] d_loss: 1.3413 g_loss: 0.5813
# Epoch [14/200] Batch [1100/1249] d_loss: 1.1226 g_loss: 0.8437
# Epoch [14/200] Batch [1150/1249] d_loss: 1.3478 g_loss: 0.6901
# Epoch [14/200] Batch [1200/1249] d_loss: 1.1754 g_loss: 0.9439
# Epoch [15/200] Batch [0/1249] d_loss: 1.2546 g_loss: 0.6689
# Epoch [15/200] Batch [50/1249] d_loss: 1.1684 g_loss: 1.0402
# Epoch [15/200] Batch [100/1249] d_loss: 1.3178 g_loss: 0.9955
# Epoch [15/200] Batch [150/1249] d_loss: 1.2974 g_loss: 1.2963
# Epoch [15/200] Batch [200/1249] d_loss: 1.2110 g_loss: 1.3864
# Epoch [15/200] Batch [250/1249] d_loss: 1.2721 g_loss: 0.6522
# Epoch [15/200] Batch [300/1249] d_loss: 1.3525 g_loss: 0.7384
# Epoch [15/200] Batch [350/1249] d_loss: 1.0833 g_loss: 1.0213
# Epoch [15/200] Batch [400/1249] d_loss: 1.3460 g_loss: 0.4857
# Epoch [15/200] Batch [450/1249] d_loss: 1.1417 g_loss: 0.7658
# Epoch [15/200] Batch [500/1249] d_loss: 1.3887 g_loss: 0.5622
# Epoch [15/200] Batch [550/1249] d_loss: 1.3095 g_loss: 0.5274
# Epoch [15/200] Batch [600/1249] d_loss: 1.2408 g_loss: 0.7119
# Epoch [15/200] Batch [650/1249] d_loss: 1.4482 g_loss: 1.2660
# Epoch [15/200] Batch [700/1249] d_loss: 1.2327 g_loss: 1.2068
# Epoch [15/200] Batch [750/1249] d_loss: 1.5378 g_loss: 1.6450
# Epoch [15/200] Batch [800/1249] d_loss: 1.2292 g_loss: 0.7453
# Epoch [15/200] Batch [850/1249] d_loss: 1.2135 g_loss: 0.9653
# Epoch [15/200] Batch [900/1249] d_loss: 1.2272 g_loss: 0.6425
# Epoch [15/200] Batch [950/1249] d_loss: 1.0699 g_loss: 0.7225
# Epoch [15/200] Batch [1000/1249] d_loss: 1.3485 g_loss: 1.0936
# Epoch [15/200] Batch [1050/1249] d_loss: 1.2615 g_loss: 1.2977
# Epoch [15/200] Batch [1100/1249] d_loss: 1.2487 g_loss: 1.1326
# Epoch [15/200] Batch [1150/1249] d_loss: 1.0757 g_loss: 0.9319
# Epoch [15/200] Batch [1200/1249] d_loss: 1.5494 g_loss: 1.3862
# Epoch [16/200] Batch [0/1249] d_loss: 1.3377 g_loss: 1.2342
# Epoch [16/200] Batch [50/1249] d_loss: 1.1370 g_loss: 0.7405
# Epoch [16/200] Batch [100/1249] d_loss: 1.3060 g_loss: 1.2998
# Epoch [16/200] Batch [150/1249] d_loss: 1.2841 g_loss: 1.4883
# Epoch [16/200] Batch [200/1249] d_loss: 1.3556 g_loss: 0.9524
# Epoch [16/200] Batch [250/1249] d_loss: 1.2328 g_loss: 0.5885
# Epoch [16/200] Batch [300/1249] d_loss: 1.2326 g_loss: 1.4337
# Epoch [16/200] Batch [350/1249] d_loss: 1.0520 g_loss: 0.6888
# Epoch [16/200] Batch [400/1249] d_loss: 1.2318 g_loss: 0.7845
# Epoch [16/200] Batch [450/1249] d_loss: 1.1008 g_loss: 1.1781
# Epoch [16/200] Batch [500/1249] d_loss: 1.1263 g_loss: 0.8812
# Epoch [16/200] Batch [550/1249] d_loss: 1.1420 g_loss: 0.8660
# Epoch [16/200] Batch [600/1249] d_loss: 1.5286 g_loss: 1.3237
# Epoch [16/200] Batch [650/1249] d_loss: 1.1589 g_loss: 1.2827
# Epoch [16/200] Batch [700/1249] d_loss: 1.1204 g_loss: 1.0420
# Epoch [16/200] Batch [750/1249] d_loss: 1.2332 g_loss: 1.1869
# Epoch [16/200] Batch [800/1249] d_loss: 1.0702 g_loss: 1.2837
# Epoch [16/200] Batch [850/1249] d_loss: 1.1895 g_loss: 0.6851
# Epoch [16/200] Batch [900/1249] d_loss: 1.1977 g_loss: 0.7484
# Epoch [16/200] Batch [950/1249] d_loss: 1.2641 g_loss: 1.2880
# Epoch [16/200] Batch [1000/1249] d_loss: 1.2977 g_loss: 0.6897
# Epoch [16/200] Batch [1050/1249] d_loss: 1.0794 g_loss: 1.1701
# Epoch [16/200] Batch [1100/1249] d_loss: 1.1691 g_loss: 1.1626
# Epoch [16/200] Batch [1150/1249] d_loss: 1.2966 g_loss: 0.8517
# Epoch [16/200] Batch [1200/1249] d_loss: 1.0564 g_loss: 0.9601
# Epoch [17/200] Batch [0/1249] d_loss: 1.0752 g_loss: 1.4119
# Epoch [17/200] Batch [50/1249] d_loss: 1.1698 g_loss: 0.6830
# Epoch [17/200] Batch [100/1249] d_loss: 1.2954 g_loss: 0.6208
# Epoch [17/200] Batch [150/1249] d_loss: 1.0204 g_loss: 1.2232
# Epoch [17/200] Batch [200/1249] d_loss: 1.0879 g_loss: 0.7209
# Epoch [17/200] Batch [250/1249] d_loss: 1.0877 g_loss: 0.7548
# Epoch [17/200] Batch [300/1249] d_loss: 1.2144 g_loss: 0.7176
# Epoch [17/200] Batch [350/1249] d_loss: 1.1736 g_loss: 0.8473
# Epoch [17/200] Batch [400/1249] d_loss: 1.2242 g_loss: 0.9229
# Epoch [17/200] Batch [450/1249] d_loss: 1.2645 g_loss: 1.7353
# Epoch [17/200] Batch [500/1249] d_loss: 1.2030 g_loss: 1.0707
# Epoch [17/200] Batch [550/1249] d_loss: 1.2876 g_loss: 0.8282
# Epoch [17/200] Batch [600/1249] d_loss: 1.1038 g_loss: 1.0110
# Epoch [17/200] Batch [650/1249] d_loss: 1.3414 g_loss: 1.4213
# Epoch [17/200] Batch [700/1249] d_loss: 1.4182 g_loss: 1.4038
# Epoch [17/200] Batch [750/1249] d_loss: 1.0715 g_loss: 0.9633
# Epoch [17/200] Batch [800/1249] d_loss: 1.2462 g_loss: 1.4744
# Epoch [17/200] Batch [850/1249] d_loss: 1.3070 g_loss: 1.0409
# Epoch [17/200] Batch [900/1249] d_loss: 1.1364 g_loss: 1.1726
# Epoch [17/200] Batch [950/1249] d_loss: 1.3589 g_loss: 1.3713
# Epoch [17/200] Batch [1000/1249] d_loss: 1.2451 g_loss: 0.6846
# Epoch [17/200] Batch [1050/1249] d_loss: 1.4588 g_loss: 1.0121
# Epoch [17/200] Batch [1100/1249] d_loss: 1.3307 g_loss: 1.2371
# Epoch [17/200] Batch [1150/1249] d_loss: 1.2890 g_loss: 1.1378
# Epoch [17/200] Batch [1200/1249] d_loss: 1.2044 g_loss: 0.7915
# Epoch [18/200] Batch [0/1249] d_loss: 1.2446 g_loss: 1.6293
# Epoch [18/200] Batch [50/1249] d_loss: 1.5681 g_loss: 1.8243
# Epoch [18/200] Batch [100/1249] d_loss: 1.3525 g_loss: 0.7272
# Epoch [18/200] Batch [150/1249] d_loss: 1.0454 g_loss: 1.1982
# Epoch [18/200] Batch [200/1249] d_loss: 1.1113 g_loss: 0.7396
# Epoch [18/200] Batch [250/1249] d_loss: 1.2747 g_loss: 0.9767
# Epoch [18/200] Batch [300/1249] d_loss: 1.0562 g_loss: 0.9262
# Epoch [18/200] Batch [350/1249] d_loss: 1.2640 g_loss: 1.1514
# Epoch [18/200] Batch [400/1249] d_loss: 1.1451 g_loss: 0.7906
# Epoch [18/200] Batch [450/1249] d_loss: 1.2330 g_loss: 0.6262
# Epoch [18/200] Batch [500/1249] d_loss: 1.1967 g_loss: 1.5884
# Epoch [18/200] Batch [550/1249] d_loss: 1.1581 g_loss: 1.0174
# Epoch [18/200] Batch [600/1249] d_loss: 1.1535 g_loss: 0.9770
# Epoch [18/200] Batch [650/1249] d_loss: 1.1469 g_loss: 1.5921
# Epoch [18/200] Batch [700/1249] d_loss: 1.1753 g_loss: 0.8857
# Epoch [18/200] Batch [750/1249] d_loss: 1.0531 g_loss: 1.0529
# Epoch [18/200] Batch [800/1249] d_loss: 1.2755 g_loss: 0.5803
# Epoch [18/200] Batch [850/1249] d_loss: 1.2519 g_loss: 0.7902
# Epoch [18/200] Batch [900/1249] d_loss: 1.2161 g_loss: 1.3381
# Epoch [18/200] Batch [950/1249] d_loss: 1.0406 g_loss: 1.0321
# Epoch [18/200] Batch [1000/1249] d_loss: 1.2615 g_loss: 0.8046
# Epoch [18/200] Batch [1050/1249] d_loss: 1.2101 g_loss: 1.3857
# Epoch [18/200] Batch [1100/1249] d_loss: 1.2595 g_loss: 1.1377
# Epoch [18/200] Batch [1150/1249] d_loss: 1.1977 g_loss: 0.7204
# Epoch [18/200] Batch [1200/1249] d_loss: 1.5509 g_loss: 0.4108
# Epoch [19/200] Batch [0/1249] d_loss: 1.0791 g_loss: 0.8551
# Epoch [19/200] Batch [50/1249] d_loss: 1.1178 g_loss: 1.0345
# Epoch [19/200] Batch [100/1249] d_loss: 1.1571 g_loss: 1.2223
# Epoch [19/200] Batch [150/1249] d_loss: 1.2352 g_loss: 0.6771
# Epoch [19/200] Batch [200/1249] d_loss: 1.2849 g_loss: 1.5857
# Epoch [19/200] Batch [250/1249] d_loss: 1.2374 g_loss: 0.6778
# Epoch [19/200] Batch [300/1249] d_loss: 1.1248 g_loss: 0.8047
# Epoch [19/200] Batch [350/1249] d_loss: 1.2205 g_loss: 0.7952
# Epoch [19/200] Batch [400/1249] d_loss: 1.3352 g_loss: 0.9449
# Epoch [19/200] Batch [450/1249] d_loss: 1.0103 g_loss: 1.6658
# Epoch [19/200] Batch [500/1249] d_loss: 1.0167 g_loss: 1.3420
# Epoch [19/200] Batch [550/1249] d_loss: 1.2343 g_loss: 1.6765
# Epoch [19/200] Batch [600/1249] d_loss: 1.3174 g_loss: 1.3494
# Epoch [19/200] Batch [650/1249] d_loss: 1.2344 g_loss: 1.0730
# Epoch [19/200] Batch [700/1249] d_loss: 1.0782 g_loss: 1.3010
# Epoch [19/200] Batch [750/1249] d_loss: 1.3652 g_loss: 0.6559
# Epoch [19/200] Batch [800/1249] d_loss: 1.1459 g_loss: 1.0289
# Epoch [19/200] Batch [850/1249] d_loss: 1.2174 g_loss: 0.8655
# Epoch [19/200] Batch [900/1249] d_loss: 1.3939 g_loss: 1.0645
# Epoch [19/200] Batch [950/1249] d_loss: 1.0634 g_loss: 0.8868
# Epoch [19/200] Batch [1000/1249] d_loss: 1.1977 g_loss: 0.7334
# Epoch [19/200] Batch [1050/1249] d_loss: 1.0176 g_loss: 1.1373
# Epoch [19/200] Batch [1100/1249] d_loss: 0.8751 g_loss: 1.2445
# Epoch [19/200] Batch [1150/1249] d_loss: 1.4663 g_loss: 0.5639
# Epoch [19/200] Batch [1200/1249] d_loss: 1.0893 g_loss: 1.4778
# Epoch [20/200] Batch [0/1249] d_loss: 1.2709 g_loss: 0.9529
# Epoch [20/200] Batch [50/1249] d_loss: 1.3005 g_loss: 0.8255
# Epoch [20/200] Batch [100/1249] d_loss: 1.0830 g_loss: 1.2957
# Epoch [20/200] Batch [150/1249] d_loss: 1.0172 g_loss: 1.0670
# Epoch [20/200] Batch [200/1249] d_loss: 1.1644 g_loss: 1.5752
# Epoch [20/200] Batch [250/1249] d_loss: 0.9829 g_loss: 1.0793
# Epoch [20/200] Batch [300/1249] d_loss: 1.2677 g_loss: 0.8438
# Epoch [20/200] Batch [350/1249] d_loss: 0.9414 g_loss: 1.4979
# Epoch [20/200] Batch [400/1249] d_loss: 1.0600 g_loss: 1.2223
# Epoch [20/200] Batch [450/1249] d_loss: 1.0456 g_loss: 0.9104
# Epoch [20/200] Batch [500/1249] d_loss: 0.8703 g_loss: 1.1882
# Epoch [20/200] Batch [550/1249] d_loss: 1.2643 g_loss: 0.5847
# Epoch [20/200] Batch [600/1249] d_loss: 1.0531 g_loss: 1.0224
# Epoch [20/200] Batch [650/1249] d_loss: 1.2627 g_loss: 1.3865
# Epoch [20/200] Batch [700/1249] d_loss: 1.1171 g_loss: 0.8904
# Epoch [20/200] Batch [750/1249] d_loss: 1.1026 g_loss: 0.8068
# Epoch [20/200] Batch [800/1249] d_loss: 1.1987 g_loss: 1.1043
# Epoch [20/200] Batch [850/1249] d_loss: 1.3550 g_loss: 0.7430
# Epoch [20/200] Batch [900/1249] d_loss: 1.1983 g_loss: 1.3364
# Epoch [20/200] Batch [950/1249] d_loss: 1.2536 g_loss: 0.6465
# Epoch [20/200] Batch [1000/1249] d_loss: 0.9938 g_loss: 1.2243
# Epoch [20/200] Batch [1050/1249] d_loss: 1.0741 g_loss: 0.9362
# Epoch [20/200] Batch [1100/1249] d_loss: 1.0552 g_loss: 0.9595
# Epoch [20/200] Batch [1150/1249] d_loss: 1.4562 g_loss: 0.9673
# Epoch [20/200] Batch [1200/1249] d_loss: 1.0782 g_loss: 1.0218
# Epoch [21/200] Batch [0/1249] d_loss: 1.1908 g_loss: 0.6851
# Epoch [21/200] Batch [50/1249] d_loss: 1.1552 g_loss: 1.1385
# Epoch [21/200] Batch [100/1249] d_loss: 1.0844 g_loss: 0.8340
# Epoch [21/200] Batch [150/1249] d_loss: 1.5941 g_loss: 0.5041
# Epoch [21/200] Batch [200/1249] d_loss: 1.3227 g_loss: 0.4404
# Epoch [21/200] Batch [250/1249] d_loss: 1.1725 g_loss: 0.8894
# Epoch [21/200] Batch [300/1249] d_loss: 1.4048 g_loss: 0.5317
# Epoch [21/200] Batch [350/1249] d_loss: 1.0549 g_loss: 1.3300
# Epoch [21/200] Batch [400/1249] d_loss: 0.9371 g_loss: 1.0294
# Epoch [21/200] Batch [450/1249] d_loss: 1.1162 g_loss: 1.2533
# Epoch [21/200] Batch [500/1249] d_loss: 0.9456 g_loss: 1.1259
# Epoch [21/200] Batch [550/1249] d_loss: 1.2273 g_loss: 0.8040
# Epoch [21/200] Batch [600/1249] d_loss: 1.1200 g_loss: 0.7676
# Epoch [21/200] Batch [650/1249] d_loss: 1.2176 g_loss: 0.7762
# Epoch [21/200] Batch [700/1249] d_loss: 0.8974 g_loss: 0.9581
# Epoch [21/200] Batch [750/1249] d_loss: 1.3509 g_loss: 1.5370
# Epoch [21/200] Batch [800/1249] d_loss: 0.9959 g_loss: 1.2801
# Epoch [21/200] Batch [850/1249] d_loss: 0.9542 g_loss: 1.5862
# Epoch [21/200] Batch [900/1249] d_loss: 0.8403 g_loss: 1.4656
# Epoch [21/200] Batch [950/1249] d_loss: 1.1772 g_loss: 0.8718
# Epoch [21/200] Batch [1000/1249] d_loss: 1.0291 g_loss: 0.9248
# Epoch [21/200] Batch [1050/1249] d_loss: 1.3948 g_loss: 1.8376
# Epoch [21/200] Batch [1100/1249] d_loss: 1.3417 g_loss: 2.0567
# Epoch [21/200] Batch [1150/1249] d_loss: 0.9232 g_loss: 1.2261
# Epoch [21/200] Batch [1200/1249] d_loss: 1.1423 g_loss: 1.0193
# Epoch [22/200] Batch [0/1249] d_loss: 1.1305 g_loss: 1.1488
# Epoch [22/200] Batch [50/1249] d_loss: 0.7761 g_loss: 1.4840
# Epoch [22/200] Batch [100/1249] d_loss: 1.1818 g_loss: 0.8026
# Epoch [22/200] Batch [150/1249] d_loss: 1.1901 g_loss: 0.9231
# Epoch [22/200] Batch [200/1249] d_loss: 1.1093 g_loss: 0.8646
# Epoch [22/200] Batch [250/1249] d_loss: 0.9040 g_loss: 1.8285
# Epoch [22/200] Batch [300/1249] d_loss: 1.1783 g_loss: 1.1214
# Epoch [22/200] Batch [350/1249] d_loss: 1.1264 g_loss: 1.7613
# Epoch [22/200] Batch [400/1249] d_loss: 1.3563 g_loss: 0.7236
# Epoch [22/200] Batch [450/1249] d_loss: 0.8710 g_loss: 1.4338
# Epoch [22/200] Batch [500/1249] d_loss: 1.0767 g_loss: 1.3905
# Epoch [22/200] Batch [550/1249] d_loss: 1.3496 g_loss: 0.4638
# Epoch [22/200] Batch [600/1249] d_loss: 1.0543 g_loss: 0.8753
# Epoch [22/200] Batch [650/1249] d_loss: 1.2641 g_loss: 0.7898
# Epoch [22/200] Batch [700/1249] d_loss: 1.1699 g_loss: 1.5995
# Epoch [22/200] Batch [750/1249] d_loss: 1.4500 g_loss: 1.4491
# Epoch [22/200] Batch [800/1249] d_loss: 1.1451 g_loss: 1.1170
# Epoch [22/200] Batch [850/1249] d_loss: 1.1763 g_loss: 0.8881
# Epoch [22/200] Batch [900/1249] d_loss: 1.0435 g_loss: 0.8027
# Epoch [22/200] Batch [950/1249] d_loss: 0.9370 g_loss: 1.1733
# Epoch [22/200] Batch [1000/1249] d_loss: 0.9007 g_loss: 0.9042
# Epoch [22/200] Batch [1050/1249] d_loss: 1.3210 g_loss: 1.9173
# Epoch [22/200] Batch [1100/1249] d_loss: 1.2400 g_loss: 1.2550
# Epoch [22/200] Batch [1150/1249] d_loss: 1.4686 g_loss: 2.0715
# Epoch [22/200] Batch [1200/1249] d_loss: 1.3833 g_loss: 1.1411
# Epoch [23/200] Batch [0/1249] d_loss: 1.0020 g_loss: 1.0372
# Epoch [23/200] Batch [50/1249] d_loss: 1.0666 g_loss: 0.8500
# Epoch [23/200] Batch [100/1249] d_loss: 1.0611 g_loss: 1.1557
# Epoch [23/200] Batch [150/1249] d_loss: 1.2743 g_loss: 0.6786
# Epoch [23/200] Batch [200/1249] d_loss: 1.1032 g_loss: 0.7304
# Epoch [23/200] Batch [250/1249] d_loss: 1.0263 g_loss: 1.3284
# Epoch [23/200] Batch [300/1249] d_loss: 1.2300 g_loss: 1.2490
# Epoch [23/200] Batch [350/1249] d_loss: 1.3043 g_loss: 0.7871
# Epoch [23/200] Batch [400/1249] d_loss: 0.9633 g_loss: 1.0239
# Epoch [23/200] Batch [450/1249] d_loss: 1.1869 g_loss: 1.2288
# Epoch [23/200] Batch [500/1249] d_loss: 1.3201 g_loss: 0.8683
# Epoch [23/200] Batch [550/1249] d_loss: 1.2336 g_loss: 0.7230
# Epoch [23/200] Batch [600/1249] d_loss: 1.1283 g_loss: 0.9926
# Epoch [23/200] Batch [650/1249] d_loss: 1.2092 g_loss: 0.8314
# Epoch [23/200] Batch [700/1249] d_loss: 1.2705 g_loss: 1.0145
# Epoch [23/200] Batch [750/1249] d_loss: 1.1448 g_loss: 1.2513
# Epoch [23/200] Batch [800/1249] d_loss: 1.0914 g_loss: 0.8323
# Epoch [23/200] Batch [850/1249] d_loss: 1.0730 g_loss: 0.9539
# Epoch [23/200] Batch [900/1249] d_loss: 1.4236 g_loss: 1.9203
# Epoch [23/200] Batch [950/1249] d_loss: 1.3351 g_loss: 0.6970
# Epoch [23/200] Batch [1000/1249] d_loss: 1.1658 g_loss: 0.8433
# Epoch [23/200] Batch [1050/1249] d_loss: 1.3281 g_loss: 0.6211
# Epoch [23/200] Batch [1100/1249] d_loss: 0.9028 g_loss: 1.1213
# Epoch [23/200] Batch [1150/1249] d_loss: 1.0248 g_loss: 1.1277
# Epoch [23/200] Batch [1200/1249] d_loss: 1.0998 g_loss: 0.8959
# Epoch [24/200] Batch [0/1249] d_loss: 0.9300 g_loss: 1.1863
# Epoch [24/200] Batch [50/1249] d_loss: 1.0141 g_loss: 1.6205
# Epoch [24/200] Batch [100/1249] d_loss: 0.8967 g_loss: 1.0781
# Epoch [24/200] Batch [150/1249] d_loss: 1.1912 g_loss: 1.0623
# Epoch [24/200] Batch [200/1249] d_loss: 1.4296 g_loss: 1.0771
# Epoch [24/200] Batch [250/1249] d_loss: 1.1284 g_loss: 0.6417
# Epoch [24/200] Batch [300/1249] d_loss: 0.9397 g_loss: 1.0805
# Epoch [24/200] Batch [350/1249] d_loss: 1.1952 g_loss: 0.5746
# Epoch [24/200] Batch [400/1249] d_loss: 1.0924 g_loss: 1.0301
# Epoch [24/200] Batch [450/1249] d_loss: 1.1594 g_loss: 0.7738
# Epoch [24/200] Batch [500/1249] d_loss: 1.0507 g_loss: 1.3653
# Epoch [24/200] Batch [550/1249] d_loss: 0.9367 g_loss: 1.6056
# Epoch [24/200] Batch [600/1249] d_loss: 1.2870 g_loss: 0.7881
# Epoch [24/200] Batch [650/1249] d_loss: 1.3461 g_loss: 0.6523
# Epoch [24/200] Batch [700/1249] d_loss: 1.2421 g_loss: 1.5268
# Epoch [24/200] Batch [750/1249] d_loss: 0.7656 g_loss: 1.3154
# Epoch [24/200] Batch [800/1249] d_loss: 1.0758 g_loss: 0.9496
# Epoch [24/200] Batch [850/1249] d_loss: 1.0746 g_loss: 1.5621
# Epoch [24/200] Batch [900/1249] d_loss: 1.0333 g_loss: 1.1824
# Epoch [24/200] Batch [950/1249] d_loss: 1.2558 g_loss: 1.4347
# Epoch [24/200] Batch [1000/1249] d_loss: 1.2131 g_loss: 1.2732
# Epoch [24/200] Batch [1050/1249] d_loss: 1.2275 g_loss: 0.8119
# Epoch [24/200] Batch [1100/1249] d_loss: 0.9807 g_loss: 1.6815
# Epoch [24/200] Batch [1150/1249] d_loss: 1.0447 g_loss: 1.0321
# Epoch [24/200] Batch [1200/1249] d_loss: 0.7511 g_loss: 1.7411
# Epoch [25/200] Batch [0/1249] d_loss: 1.0266 g_loss: 0.8168
# Epoch [25/200] Batch [50/1249] d_loss: 1.1968 g_loss: 0.9314
# Epoch [25/200] Batch [100/1249] d_loss: 1.0623 g_loss: 0.9351
# Epoch [25/200] Batch [150/1249] d_loss: 1.0465 g_loss: 1.1460
# Epoch [25/200] Batch [200/1249] d_loss: 1.1258 g_loss: 1.9299
# Epoch [25/200] Batch [250/1249] d_loss: 1.3819 g_loss: 1.8172
# Epoch [25/200] Batch [300/1249] d_loss: 1.2233 g_loss: 1.4548
# Epoch [25/200] Batch [350/1249] d_loss: 0.9671 g_loss: 0.9922
# Epoch [25/200] Batch [400/1249] d_loss: 1.2265 g_loss: 0.7129
# Epoch [25/200] Batch [450/1249] d_loss: 1.0059 g_loss: 0.9728
# Epoch [25/200] Batch [500/1249] d_loss: 1.0229 g_loss: 1.1582
# Epoch [25/200] Batch [550/1249] d_loss: 1.1604 g_loss: 0.9446
# Epoch [25/200] Batch [600/1249] d_loss: 0.7113 g_loss: 1.8059
# Epoch [25/200] Batch [650/1249] d_loss: 0.7271 g_loss: 1.4498
# Epoch [25/200] Batch [700/1249] d_loss: 1.0239 g_loss: 1.2442
# Epoch [25/200] Batch [750/1249] d_loss: 1.1162 g_loss: 1.0551
# Epoch [25/200] Batch [800/1249] d_loss: 1.4553 g_loss: 0.6208
# Epoch [25/200] Batch [850/1249] d_loss: 1.4712 g_loss: 1.4064
# Epoch [25/200] Batch [900/1249] d_loss: 0.9180 g_loss: 0.9289
# Epoch [25/200] Batch [950/1249] d_loss: 1.1427 g_loss: 1.3344
# Epoch [25/200] Batch [1000/1249] d_loss: 1.5353 g_loss: 0.4851
# Epoch [25/200] Batch [1050/1249] d_loss: 1.2159 g_loss: 1.2841
# Epoch [25/200] Batch [1100/1249] d_loss: 0.9939 g_loss: 0.9205
# Epoch [25/200] Batch [1150/1249] d_loss: 1.3067 g_loss: 0.5636
# Epoch [25/200] Batch [1200/1249] d_loss: 1.6910 g_loss: 0.6050
# Epoch [26/200] Batch [0/1249] d_loss: 1.0675 g_loss: 1.1064
# Epoch [26/200] Batch [50/1249] d_loss: 1.1419 g_loss: 0.7050
# Epoch [26/200] Batch [100/1249] d_loss: 1.0196 g_loss: 1.3181
# Epoch [26/200] Batch [150/1249] d_loss: 0.9562 g_loss: 1.0725
# Epoch [26/200] Batch [200/1249] d_loss: 1.2293 g_loss: 1.4020
# Epoch [26/200] Batch [250/1249] d_loss: 1.0070 g_loss: 0.7291
# Epoch [26/200] Batch [300/1249] d_loss: 1.3722 g_loss: 1.5718
# Epoch [26/200] Batch [350/1249] d_loss: 1.1132 g_loss: 1.1000
# Epoch [26/200] Batch [400/1249] d_loss: 0.8512 g_loss: 1.1573
# Epoch [26/200] Batch [450/1249] d_loss: 0.7704 g_loss: 1.3660
# Epoch [26/200] Batch [500/1249] d_loss: 0.9981 g_loss: 1.2011
# Epoch [26/200] Batch [550/1249] d_loss: 0.7977 g_loss: 1.3837
# Epoch [26/200] Batch [600/1249] d_loss: 1.2526 g_loss: 1.9292
# Epoch [26/200] Batch [650/1249] d_loss: 1.0178 g_loss: 1.7735
# Epoch [26/200] Batch [700/1249] d_loss: 1.3311 g_loss: 0.8471
# Epoch [26/200] Batch [750/1249] d_loss: 1.1740 g_loss: 0.4934
# Epoch [26/200] Batch [800/1249] d_loss: 1.2267 g_loss: 0.7976
# Epoch [26/200] Batch [850/1249] d_loss: 1.1996 g_loss: 0.7933
# Epoch [26/200] Batch [900/1249] d_loss: 1.2799 g_loss: 0.6893
# Epoch [26/200] Batch [950/1249] d_loss: 0.7821 g_loss: 1.4910
# Epoch [26/200] Batch [1000/1249] d_loss: 1.2595 g_loss: 1.5275
# Epoch [26/200] Batch [1050/1249] d_loss: 1.1885 g_loss: 0.8176
# Epoch [26/200] Batch [1100/1249] d_loss: 1.0774 g_loss: 0.8825
# Epoch [26/200] Batch [1150/1249] d_loss: 1.4252 g_loss: 0.5684
# Epoch [26/200] Batch [1200/1249] d_loss: 1.2088 g_loss: 1.2634
# Epoch [27/200] Batch [0/1249] d_loss: 1.1880 g_loss: 0.8247
# Epoch [27/200] Batch [50/1249] d_loss: 1.1407 g_loss: 0.9521
# Epoch [27/200] Batch [100/1249] d_loss: 1.1648 g_loss: 0.8421
# Epoch [27/200] Batch [150/1249] d_loss: 1.2721 g_loss: 1.2401
# Epoch [27/200] Batch [200/1249] d_loss: 1.0077 g_loss: 1.2666
# Epoch [27/200] Batch [250/1249] d_loss: 0.9655 g_loss: 1.3822
# Epoch [27/200] Batch [300/1249] d_loss: 0.8968 g_loss: 1.6675
# Epoch [27/200] Batch [350/1249] d_loss: 1.7007 g_loss: 2.3486
# Epoch [27/200] Batch [400/1249] d_loss: 1.3042 g_loss: 1.0411
# Epoch [27/200] Batch [450/1249] d_loss: 1.0206 g_loss: 1.0727
# Epoch [27/200] Batch [500/1249] d_loss: 0.9691 g_loss: 0.9427
# Epoch [27/200] Batch [550/1249] d_loss: 0.9930 g_loss: 1.0081
# Epoch [27/200] Batch [600/1249] d_loss: 1.0518 g_loss: 0.8256
# Epoch [27/200] Batch [650/1249] d_loss: 1.0476 g_loss: 1.3256
# Epoch [27/200] Batch [700/1249] d_loss: 1.0450 g_loss: 1.0668
# Epoch [27/200] Batch [750/1249] d_loss: 1.0486 g_loss: 1.8734
# Epoch [27/200] Batch [800/1249] d_loss: 1.3791 g_loss: 1.0913
# Epoch [27/200] Batch [850/1249] d_loss: 1.1607 g_loss: 1.6391
# Epoch [27/200] Batch [900/1249] d_loss: 1.3721 g_loss: 1.4399
# Epoch [27/200] Batch [950/1249] d_loss: 1.4379 g_loss: 1.1350
# Epoch [27/200] Batch [1000/1249] d_loss: 1.1939 g_loss: 0.9041
# Epoch [27/200] Batch [1050/1249] d_loss: 1.3029 g_loss: 0.9278
# Epoch [27/200] Batch [1100/1249] d_loss: 1.1798 g_loss: 1.3609
# Epoch [27/200] Batch [1150/1249] d_loss: 1.1811 g_loss: 0.9073
# Epoch [27/200] Batch [1200/1249] d_loss: 1.1063 g_loss: 0.7687
# Epoch [28/200] Batch [0/1249] d_loss: 1.2163 g_loss: 1.3763
# Epoch [28/200] Batch [50/1249] d_loss: 1.1765 g_loss: 1.1659
# Epoch [28/200] Batch [100/1249] d_loss: 0.9898 g_loss: 0.9945
# Epoch [28/200] Batch [150/1249] d_loss: 1.1663 g_loss: 1.4957
# Epoch [28/200] Batch [200/1249] d_loss: 1.1614 g_loss: 0.7462
# Epoch [28/200] Batch [250/1249] d_loss: 0.7919 g_loss: 2.0630
# Epoch [28/200] Batch [300/1249] d_loss: 0.8671 g_loss: 1.1200
# Epoch [28/200] Batch [350/1249] d_loss: 1.4300 g_loss: 0.5919
# Epoch [28/200] Batch [400/1249] d_loss: 1.0650 g_loss: 1.0154
# Epoch [28/200] Batch [450/1249] d_loss: 0.8883 g_loss: 1.0941
# Epoch [28/200] Batch [500/1249] d_loss: 0.8630 g_loss: 1.2470
# Epoch [28/200] Batch [550/1249] d_loss: 1.5874 g_loss: 1.0683
# Epoch [28/200] Batch [600/1249] d_loss: 1.3335 g_loss: 0.6171
# Epoch [28/200] Batch [650/1249] d_loss: 1.1132 g_loss: 1.4573
# Epoch [28/200] Batch [700/1249] d_loss: 0.8904 g_loss: 1.4270
# Epoch [28/200] Batch [750/1249] d_loss: 1.1090 g_loss: 0.7404
# Epoch [28/200] Batch [800/1249] d_loss: 0.9953 g_loss: 1.7758
# Epoch [28/200] Batch [850/1249] d_loss: 1.2782 g_loss: 1.9995
# Epoch [28/200] Batch [900/1249] d_loss: 1.1120 g_loss: 1.9331
# Epoch [28/200] Batch [950/1249] d_loss: 0.9484 g_loss: 1.6565
# Epoch [28/200] Batch [1000/1249] d_loss: 1.0996 g_loss: 1.2243
# Epoch [28/200] Batch [1050/1249] d_loss: 1.0865 g_loss: 1.4583
# Epoch [28/200] Batch [1100/1249] d_loss: 1.3575 g_loss: 0.6418
# Epoch [28/200] Batch [1150/1249] d_loss: 1.3487 g_loss: 1.4227
# Epoch [28/200] Batch [1200/1249] d_loss: 1.2709 g_loss: 0.5858
# Epoch [29/200] Batch [0/1249] d_loss: 0.7570 g_loss: 1.1916
# Epoch [29/200] Batch [50/1249] d_loss: 1.3596 g_loss: 0.6876
# Epoch [29/200] Batch [100/1249] d_loss: 1.0294 g_loss: 1.4790
# Epoch [29/200] Batch [150/1249] d_loss: 1.0208 g_loss: 1.1479
# Epoch [29/200] Batch [200/1249] d_loss: 0.8779 g_loss: 1.3032
# Epoch [29/200] Batch [250/1249] d_loss: 1.1802 g_loss: 0.8593
# Epoch [29/200] Batch [300/1249] d_loss: 1.1894 g_loss: 0.9948
# Epoch [29/200] Batch [350/1249] d_loss: 1.1280 g_loss: 1.1228
# Epoch [29/200] Batch [400/1249] d_loss: 0.9130 g_loss: 0.9349
# Epoch [29/200] Batch [450/1249] d_loss: 1.3530 g_loss: 0.9647
# Epoch [29/200] Batch [500/1249] d_loss: 1.2789 g_loss: 1.4513
# Epoch [29/200] Batch [550/1249] d_loss: 1.1282 g_loss: 1.2077
# Epoch [29/200] Batch [600/1249] d_loss: 1.1644 g_loss: 0.9309
# Epoch [29/200] Batch [650/1249] d_loss: 0.9028 g_loss: 1.2443
# Epoch [29/200] Batch [700/1249] d_loss: 1.1706 g_loss: 1.8558
# Epoch [29/200] Batch [750/1249] d_loss: 1.0574 g_loss: 1.0367
# Epoch [29/200] Batch [800/1249] d_loss: 1.3337 g_loss: 0.5311
# Epoch [29/200] Batch [850/1249] d_loss: 1.2688 g_loss: 0.6111
# Epoch [29/200] Batch [900/1249] d_loss: 1.0278 g_loss: 0.9520
# Epoch [29/200] Batch [950/1249] d_loss: 0.9041 g_loss: 1.4541
# Epoch [29/200] Batch [1000/1249] d_loss: 0.8282 g_loss: 1.3571
# Epoch [29/200] Batch [1050/1249] d_loss: 0.9591 g_loss: 1.2366
# Epoch [29/200] Batch [1100/1249] d_loss: 0.9916 g_loss: 1.3779
# Epoch [29/200] Batch [1150/1249] d_loss: 0.9028 g_loss: 2.2998
# Epoch [29/200] Batch [1200/1249] d_loss: 0.5799 g_loss: 1.9813
# Epoch [30/200] Batch [0/1249] d_loss: 1.0382 g_loss: 0.7639
# Epoch [30/200] Batch [50/1249] d_loss: 0.8597 g_loss: 1.1663
# Epoch [30/200] Batch [100/1249] d_loss: 0.9654 g_loss: 1.4572
# Epoch [30/200] Batch [150/1249] d_loss: 1.1812 g_loss: 0.7154
# Epoch [30/200] Batch [200/1249] d_loss: 0.7911 g_loss: 1.8071
# Epoch [30/200] Batch [250/1249] d_loss: 1.1650 g_loss: 0.8987
# Epoch [30/200] Batch [300/1249] d_loss: 1.1244 g_loss: 1.2672
# Epoch [30/200] Batch [350/1249] d_loss: 1.1526 g_loss: 0.8172
# Epoch [30/200] Batch [400/1249] d_loss: 1.2343 g_loss: 1.0461
# Epoch [30/200] Batch [450/1249] d_loss: 1.2894 g_loss: 1.6753
# Epoch [30/200] Batch [500/1249] d_loss: 0.8275 g_loss: 1.0320
# Epoch [30/200] Batch [550/1249] d_loss: 0.8107 g_loss: 1.1364
# Epoch [30/200] Batch [600/1249] d_loss: 0.9263 g_loss: 1.2286
# Epoch [30/200] Batch [650/1249] d_loss: 1.0067 g_loss: 1.5651
# Epoch [30/200] Batch [700/1249] d_loss: 0.8234 g_loss: 1.1218
# Epoch [30/200] Batch [750/1249] d_loss: 1.0019 g_loss: 1.7169
# Epoch [30/200] Batch [800/1249] d_loss: 1.0797 g_loss: 1.0933
# Epoch [30/200] Batch [850/1249] d_loss: 1.1785 g_loss: 0.6486
# ...
# Epoch [189/200] Batch [1100/1249] d_loss: 0.1831 g_loss: 2.7360
# Epoch [189/200] Batch [1150/1249] d_loss: 1.0155 g_loss: 1.8884
# Epoch [189/200] Batch [1200/1249] d_loss: 0.1954 g_loss: 3.0111
# Epoch [190/200] Batch [0/1249] d_loss: 0.7023 g_loss: 2.9350
# Epoch [190/200] Batch [50/1249] d_loss: 0.2308 g_loss: 2.8253
# Epoch [190/200] Batch [100/1249] d_loss: 0.6702 g_loss: 3.6388
# Epoch [190/200] Batch [150/1249] d_loss: 0.9137 g_loss: 1.4041
# Epoch [190/200] Batch [200/1249] d_loss: 0.4526 g_loss: 2.2708
# Epoch [190/200] Batch [250/1249] d_loss: 0.6548 g_loss: 1.5429
# Epoch [190/200] Batch [300/1249] d_loss: 0.3505 g_loss: 2.6863
# Epoch [190/200] Batch [350/1249] d_loss: 0.3714 g_loss: 3.9405
# Epoch [190/200] Batch [400/1249] d_loss: 0.6257 g_loss: 1.7992
# Epoch [190/200] Batch [450/1249] d_loss: 0.7399 g_loss: 1.4703
# Epoch [190/200] Batch [500/1249] d_loss: 0.5392 g_loss: 2.5597
# Epoch [190/200] Batch [550/1249] d_loss: 0.3452 g_loss: 2.3298
# Epoch [190/200] Batch [600/1249] d_loss: 0.3724 g_loss: 2.2943
# Epoch [190/200] Batch [650/1249] d_loss: 0.4764 g_loss: 2.1137
# Epoch [190/200] Batch [700/1249] d_loss: 0.1674 g_loss: 4.7665
# Epoch [190/200] Batch [750/1249] d_loss: 0.2974 g_loss: 3.3204
# Epoch [190/200] Batch [800/1249] d_loss: 0.6919 g_loss: 1.8197
# Epoch [190/200] Batch [850/1249] d_loss: 0.8586 g_loss: 1.1333
# Epoch [190/200] Batch [900/1249] d_loss: 0.1786 g_loss: 2.6078
# Epoch [190/200] Batch [950/1249] d_loss: 0.6476 g_loss: 1.7276
# Epoch [190/200] Batch [1000/1249] d_loss: 0.3439 g_loss: 2.5083
# Epoch [190/200] Batch [1050/1249] d_loss: 0.6578 g_loss: 1.9935
# Epoch [190/200] Batch [1100/1249] d_loss: 0.8487 g_loss: 1.5632
# Epoch [190/200] Batch [1150/1249] d_loss: 0.4616 g_loss: 2.2685
# Epoch [190/200] Batch [1200/1249] d_loss: 0.5992 g_loss: 1.9603
# Epoch [191/200] Batch [0/1249] d_loss: 0.2762 g_loss: 2.9171
# Epoch [191/200] Batch [50/1249] d_loss: 0.2394 g_loss: 3.5571
# Epoch [191/200] Batch [100/1249] d_loss: 0.6655 g_loss: 1.9249
# Epoch [191/200] Batch [150/1249] d_loss: 0.2617 g_loss: 2.3585
# Epoch [191/200] Batch [200/1249] d_loss: 0.5889 g_loss: 1.8128
# Epoch [191/200] Batch [250/1249] d_loss: 0.7380 g_loss: 1.8975
# Epoch [191/200] Batch [300/1249] d_loss: 0.5801 g_loss: 3.2226
# Epoch [191/200] Batch [350/1249] d_loss: 0.6238 g_loss: 2.6300
# Epoch [191/200] Batch [400/1249] d_loss: 0.2235 g_loss: 3.4988
# Epoch [191/200] Batch [450/1249] d_loss: 0.3832 g_loss: 2.2762
# Epoch [191/200] Batch [500/1249] d_loss: 0.4259 g_loss: 2.7549
# Epoch [191/200] Batch [550/1249] d_loss: 0.8713 g_loss: 1.3703
# Epoch [191/200] Batch [600/1249] d_loss: 1.0637 g_loss: 1.5339
# Epoch [191/200] Batch [650/1249] d_loss: 0.6150 g_loss: 2.5331
# Epoch [191/200] Batch [700/1249] d_loss: 0.9205 g_loss: 1.5254
# Epoch [191/200] Batch [750/1249] d_loss: 0.6898 g_loss: 2.3629
# Epoch [191/200] Batch [800/1249] d_loss: 0.1581 g_loss: 2.6735
# Epoch [191/200] Batch [850/1249] d_loss: 0.5570 g_loss: 2.6691
# Epoch [191/200] Batch [900/1249] d_loss: 0.9839 g_loss: 2.4918
# Epoch [191/200] Batch [950/1249] d_loss: 0.8049 g_loss: 2.2714
# Epoch [191/200] Batch [1000/1249] d_loss: 0.7631 g_loss: 2.1057
# Epoch [191/200] Batch [1050/1249] d_loss: 0.2074 g_loss: 3.8349
# Epoch [191/200] Batch [1100/1249] d_loss: 0.3477 g_loss: 2.2209
# Epoch [191/200] Batch [1150/1249] d_loss: 0.3002 g_loss: 2.4762
# Epoch [191/200] Batch [1200/1249] d_loss: 0.4012 g_loss: 2.2693
# Epoch [192/200] Batch [0/1249] d_loss: 0.4694 g_loss: 3.7199
# Epoch [192/200] Batch [50/1249] d_loss: 0.6848 g_loss: 1.3129
# Epoch [192/200] Batch [100/1249] d_loss: 0.2158 g_loss: 3.8695
# Epoch [192/200] Batch [150/1249] d_loss: 0.5628 g_loss: 1.4963
# Epoch [192/200] Batch [200/1249] d_loss: 0.2272 g_loss: 2.7055
# Epoch [192/200] Batch [250/1249] d_loss: 1.2310 g_loss: 0.9765
# Epoch [192/200] Batch [300/1249] d_loss: 0.5721 g_loss: 2.7753
# Epoch [192/200] Batch [350/1249] d_loss: 0.8080 g_loss: 1.4439
# Epoch [192/200] Batch [400/1249] d_loss: 0.3889 g_loss: 2.4070
# Epoch [192/200] Batch [450/1249] d_loss: 1.0586 g_loss: 1.4082
# Epoch [192/200] Batch [500/1249] d_loss: 0.5834 g_loss: 1.5337
# Epoch [192/200] Batch [550/1249] d_loss: 0.4061 g_loss: 2.1259
# Epoch [192/200] Batch [600/1249] d_loss: 0.5786 g_loss: 2.2388
# Epoch [192/200] Batch [650/1249] d_loss: 0.3623 g_loss: 2.8579
# Epoch [192/200] Batch [700/1249] d_loss: 0.9275 g_loss: 1.2293
# Epoch [192/200] Batch [750/1249] d_loss: 0.4559 g_loss: 2.4915
# Epoch [192/200] Batch [800/1249] d_loss: 0.3460 g_loss: 2.3197
# Epoch [192/200] Batch [850/1249] d_loss: 0.7912 g_loss: 1.6106
# Epoch [192/200] Batch [900/1249] d_loss: 0.9269 g_loss: 1.6745
# Epoch [192/200] Batch [950/1249] d_loss: 0.3476 g_loss: 2.4649
# Epoch [192/200] Batch [1000/1249] d_loss: 0.3746 g_loss: 2.3317
# Epoch [192/200] Batch [1050/1249] d_loss: 0.7164 g_loss: 2.6601
# Epoch [192/200] Batch [1100/1249] d_loss: 0.6888 g_loss: 1.9844
# Epoch [192/200] Batch [1150/1249] d_loss: 1.6398 g_loss: 1.0269
# Epoch [192/200] Batch [1200/1249] d_loss: 0.5606 g_loss: 2.1471
# Epoch [193/200] Batch [0/1249] d_loss: 0.8824 g_loss: 2.1168
# Epoch [193/200] Batch [50/1249] d_loss: 0.7331 g_loss: 1.4285
# Epoch [193/200] Batch [100/1249] d_loss: 0.5541 g_loss: 1.7272
# Epoch [193/200] Batch [150/1249] d_loss: 0.1789 g_loss: 3.1326
# Epoch [193/200] Batch [200/1249] d_loss: 0.3114 g_loss: 2.6263
# Epoch [193/200] Batch [250/1249] d_loss: 0.8158 g_loss: 3.2260
# Epoch [193/200] Batch [300/1249] d_loss: 0.8477 g_loss: 1.4840
# Epoch [193/200] Batch [350/1249] d_loss: 0.5737 g_loss: 3.5096
# Epoch [193/200] Batch [400/1249] d_loss: 0.7819 g_loss: 2.0539
# Epoch [193/200] Batch [450/1249] d_loss: 0.3316 g_loss: 2.4197
# Epoch [193/200] Batch [500/1249] d_loss: 0.6108 g_loss: 2.9491
# Epoch [193/200] Batch [550/1249] d_loss: 0.3559 g_loss: 2.2918
# Epoch [193/200] Batch [600/1249] d_loss: 0.5548 g_loss: 1.9592
# Epoch [193/200] Batch [650/1249] d_loss: 0.4826 g_loss: 4.0443
# Epoch [193/200] Batch [700/1249] d_loss: 0.7014 g_loss: 1.7374
# Epoch [193/200] Batch [750/1249] d_loss: 0.7074 g_loss: 2.9898
# Epoch [193/200] Batch [800/1249] d_loss: 0.0510 g_loss: 3.8619
# Epoch [193/200] Batch [850/1249] d_loss: 0.6594 g_loss: 2.0788
# Epoch [193/200] Batch [900/1249] d_loss: 0.3775 g_loss: 2.7378
# Epoch [193/200] Batch [950/1249] d_loss: 0.9947 g_loss: 1.7707
# Epoch [193/200] Batch [1000/1249] d_loss: 1.4054 g_loss: 1.3074
# Epoch [193/200] Batch [1050/1249] d_loss: 1.0008 g_loss: 1.5410
# Epoch [193/200] Batch [1100/1249] d_loss: 0.3760 g_loss: 2.3977
# Epoch [193/200] Batch [1150/1249] d_loss: 0.3800 g_loss: 2.3627
# Epoch [193/200] Batch [1200/1249] d_loss: 0.4580 g_loss: 4.5307
# Epoch [194/200] Batch [0/1249] d_loss: 0.9513 g_loss: 1.6116
# Epoch [194/200] Batch [50/1249] d_loss: 0.3865 g_loss: 2.0182
# Epoch [194/200] Batch [100/1249] d_loss: 0.3219 g_loss: 2.2295
# Epoch [194/200] Batch [150/1249] d_loss: 0.6603 g_loss: 2.0953
# Epoch [194/200] Batch [200/1249] d_loss: 0.5092 g_loss: 1.8053
# Epoch [194/200] Batch [250/1249] d_loss: 0.7117 g_loss: 2.3312
# Epoch [194/200] Batch [300/1249] d_loss: 0.7784 g_loss: 1.4307
# Epoch [194/200] Batch [350/1249] d_loss: 0.2923 g_loss: 3.0206
# Epoch [194/200] Batch [400/1249] d_loss: 0.7693 g_loss: 1.6498
# Epoch [194/200] Batch [450/1249] d_loss: 0.6307 g_loss: 1.9874
# Epoch [194/200] Batch [500/1249] d_loss: 0.8733 g_loss: 2.3505
# Epoch [194/200] Batch [550/1249] d_loss: 0.5854 g_loss: 1.8010
# Epoch [194/200] Batch [600/1249] d_loss: 1.4254 g_loss: 1.0705
# Epoch [194/200] Batch [650/1249] d_loss: 0.5868 g_loss: 2.0398
# Epoch [194/200] Batch [700/1249] d_loss: 0.7312 g_loss: 1.8059
# Epoch [194/200] Batch [750/1249] d_loss: 0.6857 g_loss: 2.0552
# Epoch [194/200] Batch [800/1249] d_loss: 0.6435 g_loss: 2.2172
# Epoch [194/200] Batch [850/1249] d_loss: 1.1444 g_loss: 1.6454
# Epoch [194/200] Batch [900/1249] d_loss: 0.4481 g_loss: 1.8394
# Epoch [194/200] Batch [950/1249] d_loss: 0.1500 g_loss: 3.4322
# Epoch [194/200] Batch [1000/1249] d_loss: 0.7482 g_loss: 1.5987
# Epoch [194/200] Batch [1050/1249] d_loss: 0.4215 g_loss: 2.0783
# Epoch [194/200] Batch [1100/1249] d_loss: 0.5673 g_loss: 2.0807
# Epoch [194/200] Batch [1150/1249] d_loss: 0.6681 g_loss: 2.9735
# Epoch [194/200] Batch [1200/1249] d_loss: 0.6703 g_loss: 1.7566
# Epoch [195/200] Batch [0/1249] d_loss: 0.4700 g_loss: 2.3098
# Epoch [195/200] Batch [50/1249] d_loss: 0.8228 g_loss: 1.5587
# Epoch [195/200] Batch [100/1249] d_loss: 0.2587 g_loss: 2.4653
# Epoch [195/200] Batch [150/1249] d_loss: 0.3651 g_loss: 2.0756
# Epoch [195/200] Batch [200/1249] d_loss: 0.3037 g_loss: 2.1704
# Epoch [195/200] Batch [250/1249] d_loss: 0.6292 g_loss: 1.7776
# Epoch [195/200] Batch [300/1249] d_loss: 0.9095 g_loss: 1.7152
# Epoch [195/200] Batch [350/1249] d_loss: 0.3360 g_loss: 2.2403
# Epoch [195/200] Batch [400/1249] d_loss: 1.1837 g_loss: 1.4727
# Epoch [195/200] Batch [450/1249] d_loss: 0.8379 g_loss: 1.5028
# Epoch [195/200] Batch [500/1249] d_loss: 0.5982 g_loss: 2.6904
# Epoch [195/200] Batch [550/1249] d_loss: 0.7387 g_loss: 1.6083
# Epoch [195/200] Batch [600/1249] d_loss: 0.3827 g_loss: 2.1258
# Epoch [195/200] Batch [650/1249] d_loss: 0.4628 g_loss: 2.2389
# Epoch [195/200] Batch [700/1249] d_loss: 0.3430 g_loss: 2.2197
# Epoch [195/200] Batch [750/1249] d_loss: 0.5989 g_loss: 2.0687
# Epoch [195/200] Batch [800/1249] d_loss: 0.8292 g_loss: 1.8770
# Epoch [195/200] Batch [850/1249] d_loss: 0.4293 g_loss: 3.8181
# Epoch [195/200] Batch [900/1249] d_loss: 0.3919 g_loss: 1.9394
# Epoch [195/200] Batch [950/1249] d_loss: 0.8269 g_loss: 1.7601
# Epoch [195/200] Batch [1000/1249] d_loss: 0.8349 g_loss: 1.4565
# Epoch [195/200] Batch [1050/1249] d_loss: 0.6638 g_loss: 1.7469
# Epoch [195/200] Batch [1100/1249] d_loss: 0.4237 g_loss: 3.0465
# Epoch [195/200] Batch [1150/1249] d_loss: 0.7431 g_loss: 1.5608
# Epoch [195/200] Batch [1200/1249] d_loss: 0.9156 g_loss: 1.8978
# Epoch [196/200] Batch [0/1249] d_loss: 1.4531 g_loss: 1.2607
# Epoch [196/200] Batch [50/1249] d_loss: 0.5744 g_loss: 1.9151
# Epoch [196/200] Batch [100/1249] d_loss: 0.4744 g_loss: 1.8687
# Epoch [196/200] Batch [150/1249] d_loss: 0.5321 g_loss: 1.7648
# Epoch [196/200] Batch [200/1249] d_loss: 1.0721 g_loss: 1.4229
# Epoch [196/200] Batch [250/1249] d_loss: 0.3817 g_loss: 2.1300
# Epoch [196/200] Batch [300/1249] d_loss: 0.8452 g_loss: 2.5703
# Epoch [196/200] Batch [350/1249] d_loss: 0.4537 g_loss: 2.3240
# Epoch [196/200] Batch [400/1249] d_loss: 0.8196 g_loss: 1.3535
# Epoch [196/200] Batch [450/1249] d_loss: 0.4172 g_loss: 2.3931
# Epoch [196/200] Batch [500/1249] d_loss: 0.5983 g_loss: 1.9331
# Epoch [196/200] Batch [550/1249] d_loss: 1.2660 g_loss: 0.9281
# Epoch [196/200] Batch [600/1249] d_loss: 0.6721 g_loss: 3.4676
# Epoch [196/200] Batch [650/1249] d_loss: 1.0851 g_loss: 1.3644
# Epoch [196/200] Batch [700/1249] d_loss: 0.5337 g_loss: 1.7953
# Epoch [196/200] Batch [750/1249] d_loss: 0.6280 g_loss: 1.9323
# Epoch [196/200] Batch [800/1249] d_loss: 1.0112 g_loss: 1.1146
# Epoch [196/200] Batch [850/1249] d_loss: 0.6201 g_loss: 1.9862
# Epoch [196/200] Batch [900/1249] d_loss: 0.5323 g_loss: 2.0793
# Epoch [196/200] Batch [950/1249] d_loss: 1.2578 g_loss: 1.2261
# Epoch [196/200] Batch [1000/1249] d_loss: 0.9792 g_loss: 1.3120
# Epoch [196/200] Batch [1050/1249] d_loss: 0.4587 g_loss: 2.1640
# Epoch [196/200] Batch [1100/1249] d_loss: 0.5638 g_loss: 1.7517
# Epoch [196/200] Batch [1150/1249] d_loss: 0.2283 g_loss: 2.3304
# Epoch [196/200] Batch [1200/1249] d_loss: 0.5437 g_loss: 1.8196
# Epoch [197/200] Batch [0/1249] d_loss: 0.2723 g_loss: 2.4501
# Epoch [197/200] Batch [50/1249] d_loss: 0.4551 g_loss: 2.0115
# Epoch [197/200] Batch [100/1249] d_loss: 0.3497 g_loss: 2.1782
# Epoch [197/200] Batch [150/1249] d_loss: 0.2468 g_loss: 2.3634
# Epoch [197/200] Batch [200/1249] d_loss: 0.3377 g_loss: 2.0367
# Epoch [197/200] Batch [250/1249] d_loss: 0.8019 g_loss: 3.8633
# Epoch [197/200] Batch [300/1249] d_loss: 0.1593 g_loss: 2.8213
# Epoch [197/200] Batch [350/1249] d_loss: 0.7246 g_loss: 1.3901
# Epoch [197/200] Batch [400/1249] d_loss: 0.5829 g_loss: 1.7550
# Epoch [197/200] Batch [450/1249] d_loss: 0.4602 g_loss: 1.7958
# Epoch [197/200] Batch [500/1249] d_loss: 0.6878 g_loss: 2.5402
# Epoch [197/200] Batch [550/1249] d_loss: 0.4448 g_loss: 1.9513
# Epoch [197/200] Batch [600/1249] d_loss: 0.5862 g_loss: 1.6444
# Epoch [197/200] Batch [650/1249] d_loss: 0.3780 g_loss: 2.1614
# Epoch [197/200] Batch [700/1249] d_loss: 0.5126 g_loss: 2.6873
# Epoch [197/200] Batch [750/1249] d_loss: 0.4768 g_loss: 3.0411
# Epoch [197/200] Batch [800/1249] d_loss: 0.6120 g_loss: 1.9597
# Epoch [197/200] Batch [850/1249] d_loss: 0.6563 g_loss: 1.9183
# Epoch [197/200] Batch [900/1249] d_loss: 0.1915 g_loss: 3.5650
# Epoch [197/200] Batch [950/1249] d_loss: 0.4888 g_loss: 2.0272
# Epoch [197/200] Batch [1000/1249] d_loss: 0.4152 g_loss: 2.5150
# Epoch [197/200] Batch [1050/1249] d_loss: 0.7547 g_loss: 1.2568
# Epoch [197/200] Batch [1100/1249] d_loss: 0.3762 g_loss: 2.9906
# Epoch [197/200] Batch [1150/1249] d_loss: 0.3358 g_loss: 2.6985
# Epoch [197/200] Batch [1200/1249] d_loss: 0.4593 g_loss: 1.9017
# Epoch [198/200] Batch [0/1249] d_loss: 0.4079 g_loss: 3.2149
# Epoch [198/200] Batch [50/1249] d_loss: 0.3836 g_loss: 2.0825
# Epoch [198/200] Batch [100/1249] d_loss: 0.8546 g_loss: 1.7352
# Epoch [198/200] Batch [150/1249] d_loss: 0.2777 g_loss: 3.1951
# Epoch [198/200] Batch [200/1249] d_loss: 0.6047 g_loss: 1.8056
# Epoch [198/200] Batch [250/1249] d_loss: 0.3074 g_loss: 2.6501
# Epoch [198/200] Batch [300/1249] d_loss: 0.4237 g_loss: 2.1307
# Epoch [198/200] Batch [350/1249] d_loss: 0.3643 g_loss: 2.3764
# Epoch [198/200] Batch [400/1249] d_loss: 0.7757 g_loss: 2.5897
# Epoch [198/200] Batch [450/1249] d_loss: 0.3364 g_loss: 3.1014
# Epoch [198/200] Batch [500/1249] d_loss: 0.5164 g_loss: 1.6486
# Epoch [198/200] Batch [550/1249] d_loss: 0.3171 g_loss: 2.2077
# Epoch [198/200] Batch [600/1249] d_loss: 0.4114 g_loss: 2.1753
# Epoch [198/200] Batch [650/1249] d_loss: 0.2509 g_loss: 2.3073
# Epoch [198/200] Batch [700/1249] d_loss: 0.4224 g_loss: 3.0464
# Epoch [198/200] Batch [750/1249] d_loss: 0.1491 g_loss: 3.5769
# Epoch [198/200] Batch [800/1249] d_loss: 1.0857 g_loss: 2.4681
# Epoch [198/200] Batch [850/1249] d_loss: 0.3178 g_loss: 2.1112
# Epoch [198/200] Batch [900/1249] d_loss: 0.6496 g_loss: 2.4854
# Epoch [198/200] Batch [950/1249] d_loss: 0.3326 g_loss: 2.3963
# Epoch [198/200] Batch [1000/1249] d_loss: 0.6983 g_loss: 2.2628
# Epoch [198/200] Batch [1050/1249] d_loss: 0.2885 g_loss: 2.9478
# Epoch [198/200] Batch [1100/1249] d_loss: 0.5331 g_loss: 1.8902
# Epoch [198/200] Batch [1150/1249] d_loss: 0.6930 g_loss: 2.0693
# Epoch [198/200] Batch [1200/1249] d_loss: 0.2388 g_loss: 4.3144
# Epoch [199/200] Batch [0/1249] d_loss: 0.5467 g_loss: 2.0303
# Epoch [199/200] Batch [50/1249] d_loss: 0.2841 g_loss: 2.3957
# Epoch [199/200] Batch [100/1249] d_loss: 0.5587 g_loss: 2.2836
# Epoch [199/200] Batch [150/1249] d_loss: 0.5711 g_loss: 1.8424
# Epoch [199/200] Batch [200/1249] d_loss: 0.6910 g_loss: 1.5441
# Epoch [199/200] Batch [250/1249] d_loss: 1.1916 g_loss: 1.5294
# Epoch [199/200] Batch [300/1249] d_loss: 0.3770 g_loss: 2.3284
# Epoch [199/200] Batch [350/1249] d_loss: 0.3256 g_loss: 2.6931
# Epoch [199/200] Batch [400/1249] d_loss: 0.3144 g_loss: 6.8118
# Epoch [199/200] Batch [450/1249] d_loss: 0.7410 g_loss: 3.1674
# Epoch [199/200] Batch [500/1249] d_loss: 1.6049 g_loss: 0.9031
# Epoch [199/200] Batch [550/1249] d_loss: 0.5817 g_loss: 2.4184
# Epoch [199/200] Batch [600/1249] d_loss: 0.5006 g_loss: 2.1782
# Epoch [199/200] Batch [650/1249] d_loss: 0.4206 g_loss: 2.8857
# Epoch [199/200] Batch [700/1249] d_loss: 1.1224 g_loss: 1.5362
# Epoch [199/200] Batch [750/1249] d_loss: 0.3049 g_loss: 2.2218
# Epoch [199/200] Batch [800/1249] d_loss: 0.7834 g_loss: 1.9966
# Epoch [199/200] Batch [850/1249] d_loss: 0.9432 g_loss: 2.1535
# Epoch [199/200] Batch [900/1249] d_loss: 0.1811 g_loss: 3.4545
# Epoch [199/200] Batch [950/1249] d_loss: 1.1118 g_loss: 1.4146
# Epoch [199/200] Batch [1000/1249] d_loss: 0.3365 g_loss: 2.4010
# Epoch [199/200] Batch [1050/1249] d_loss: 0.7041 g_loss: 2.0334
# Epoch [199/200] Batch [1100/1249] d_loss: 0.6621 g_loss: 3.0051
# Epoch [199/200] Batch [1150/1249] d_loss: 1.6509 g_loss: 3.5655
# Epoch [199/200] Batch [1200/1249] d_loss: 0.5606 g_loss: 1.9279

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# from torch.utils.data import Dataset, DataLoader
# import matplotlib.pyplot as plt
# from torchvision import transforms
# from PIL import Image
# import os
# import numpy as np
# import gc
# from torch.cuda.amp import autocast, GradScaler

# class FaceDataset(Dataset):
#     def __init__(self, root_dir, image_size=128):  # Reduced default image size
#         self.root_dir = root_dir
#         self.image_size = image_size
#         self.transform = transforms.Compose([
#             transforms.Resize((image_size, image_size)),
#             transforms.ToTensor(),
#             transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
#         ])
#         self.image_files = [
#             os.path.join(root_dir, f) for f in os.listdir(root_dir) 
#             if f.endswith('.jpg')
#         ]
    
#     def __len__(self):
#         return len(self.image_files)
    
#     def __getitem__(self, idx):
#         img_path = self.image_files[idx]
#         image = Image.open(img_path).convert('RGB')
#         return self.transform(image)

# class MappingNetwork(nn.Module):
#     def __init__(self, latent_dim=512, n_layers=4):  # Reduced number of layers
#         super().__init__()
#         layers = []
#         for i in range(n_layers):
#             layers.extend([
#                 nn.Linear(latent_dim, latent_dim),
#                 nn.LeakyReLU(0.2),
#                 nn.BatchNorm1d(latent_dim)
#             ])
#         self.mapping = nn.Sequential(*layers)
    
#     def forward(self, z):
#         return self.mapping(z)

# class AdaIN(nn.Module):
#     def __init__(self, channels):
#         super().__init__()
#         self.channels = channels
    
#     def forward(self, x, style):
#         batch = x.size(0)
#         mean = x.mean(dim=[2, 3], keepdim=True)
#         var = x.var(dim=[2, 3], keepdim=True) + 1e-8
#         x = (x - mean) / torch.sqrt(var)
        
#         style = style.view(batch, 2, self.channels, 1, 1)
#         return x * style[:, 0] + style[:, 1]

# class GeneratorBlock(nn.Module):
#     def __init__(self, in_channels, out_channels, w_dim):
#         super().__init__()
#         self.conv1 = nn.Conv2d(in_channels, out_channels, 3, padding=1)
#         self.conv2 = nn.Conv2d(out_channels, out_channels, 3, padding=1)
#         self.adain1 = AdaIN(out_channels)
#         self.adain2 = AdaIN(out_channels)
#         self.style1 = nn.Linear(w_dim, out_channels * 2)
#         self.style2 = nn.Linear(w_dim, out_channels * 2)
        
#     def forward(self, x, w):
#         s1 = self.style1(w)
#         s2 = self.style2(w)
        
#         x = self.conv1(x)
#         x = self.adain1(x, s1)
#         x = F.leaky_relu(x, 0.2)
        
#         x = self.conv2(x)
#         x = self.adain2(x, s2)
#         x = F.leaky_relu(x, 0.2)
        
#         return x

# class StyleGANGenerator(nn.Module):
#     def __init__(self, latent_dim=512, n_layers=5):  # Reduced number of layers
#         super().__init__()
#         self.mapping = MappingNetwork(latent_dim)
#         self.constant = nn.Parameter(torch.randn(1, 512, 4, 4))
        
#         # Reduced number of channels
#         channels = [512, 256, 128, 64, 32, 16]
        
#         self.blocks = nn.ModuleList()
#         for i in range(n_layers):
#             in_ch = channels[i]
#             out_ch = channels[i + 1] if i < len(channels) - 1 else channels[-1]
#             self.blocks.append(GeneratorBlock(in_ch, out_ch, latent_dim))
            
#         self.to_rgb = nn.Conv2d(16, 3, 1)
        
#     def forward(self, z):
#         batch_size = z.size(0)
#         w = self.mapping(z)
#         x = self.constant.repeat(batch_size, 1, 1, 1)
        
#         for block in self.blocks:
#             x = F.interpolate(x, scale_factor=2, mode='bilinear', align_corners=False)
#             x = block(x, w)
        
#         return torch.tanh(self.to_rgb(x))

# class StyleGANDiscriminator(nn.Module):
#     def __init__(self, n_layers=5):  # Reduced number of layers
#         super().__init__()
#         # Reduced number of channels
#         channels = [16, 32, 64, 128, 256, 512]
        
#         self.from_rgb = nn.Conv2d(3, channels[0], 1)
        
#         self.blocks = nn.ModuleList()
#         for i in range(n_layers):
#             self.blocks.append(nn.Sequential(
#                 nn.Conv2d(channels[i], channels[i+1], 3, padding=1),
#                 nn.LeakyReLU(0.2),
#                 nn.AvgPool2d(2)
#             ))
            
#         self.final = nn.Sequential(
#             nn.Flatten(),
#             nn.Linear(channels[-1] * 4 * 4, 1)
#         )
        
#     def forward(self, x):
#         x = F.leaky_relu(self.from_rgb(x), 0.2)
        
#         for block in self.blocks:
#             x = block(x)
            
#         return self.final(x)

# # def train_stylegan(train_dir, test_dir, num_epochs=100, batch_size=8):  # Reduced batch size
# #     device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
# #     # Initialize dataset with smaller image size
# #     train_dataset = FaceDataset(train_dir, image_size=128)
# #     train_loader = DataLoader(
# #         train_dataset, 
# #         batch_size=batch_size, 
# #         shuffle=True,
# #         num_workers=2,  # Reduced number of workers
# #         pin_memory=True
# #     )
    
# #     generator = StyleGANGenerator().to(device)
# #     discriminator = StyleGANDiscriminator().to(device)
    
# #     # Use mixed precision training
# #     scaler = GradScaler()
    
# #     # Use different learning rates for generator and discriminator
# #     g_optimizer = torch.optim.Adam(generator.parameters(), lr=0.0001, betas=(0.0, 0.99))
# #     d_optimizer = torch.optim.Adam(discriminator.parameters(), lr=0.0001, betas=(0.0, 0.99))
    
# #     # Learning rate schedulers
# #     g_scheduler = torch.optim.lr_scheduler.ExponentialLR(g_optimizer, gamma=0.99)
# #     d_scheduler = torch.optim.lr_scheduler.ExponentialLR(d_optimizer, gamma=0.99)
    
# #     for epoch in range(num_epochs):
# #         for batch_idx, real_images in enumerate(train_loader):
# #             real_images = real_images.to(device)
# #             batch_size = real_images.size(0)
            
# #             # Clear cache periodically
# #             if batch_idx % 10 == 0:
# #                 torch.cuda.empty_cache()
            
# #             # Train Discriminator
# #             with autocast():
# #                 d_optimizer.zero_grad()
                
# #                 label_real = torch.ones(batch_size, 1).to(device)
# #                 label_fake = torch.zeros(batch_size, 1).to(device)
                
# #                 d_output_real = discriminator(real_images)
# #                 d_loss_real = F.binary_cross_entropy_with_logits(d_output_real, label_real)
                
# #                 z = torch.randn(batch_size, 512).to(device)
# #                 fake_images = generator(z)
# #                 d_output_fake = discriminator(fake_images.detach())
# #                 d_loss_fake = F.binary_cross_entropy_with_logits(d_output_fake, label_fake)
                
# #                 d_loss = d_loss_real + d_loss_fake
            
# #             scaler.scale(d_loss).backward()
# #             scaler.step(d_optimizer)
            
# #             # Train Generator
# #             with autocast():
# #                 g_optimizer.zero_grad()
                
# #                 d_output_fake = discriminator(fake_images)
# #                 g_loss = F.binary_cross_entropy_with_logits(d_output_fake, label_real)
            
# #             scaler.scale(g_loss).backward()
# #             scaler.step(g_optimizer)
            
# #             scaler.update()
            
# #             if batch_idx % 50 == 0:
# #                 print(f'Epoch [{epoch}/{num_epochs}] Batch [{batch_idx}/{len(train_loader)}] '
# #                       f'd_loss: {d_loss.item():.4f} g_loss: {g_loss.item():.4f}')
                
# #                 # Clear some memory
# #                 del d_loss, g_loss, fake_images, real_images
# #                 torch.cuda.empty_cache()
        
# #         # Step the schedulers
# #         g_scheduler.step()
# #         d_scheduler.step()
        
# #         # Save checkpoint with memory optimization
# #         if (epoch + 1) % 10 == 0:
# #             torch.save({
# #                 'epoch': epoch,
# #                 'generator_state_dict': generator.state_dict(),
# #                 'discriminator_state_dict': discriminator.state_dict(),
# #                 'g_optimizer_state_dict': g_optimizer.state_dict(),
# #                 'd_optimizer_state_dict': d_optimizer.state_dict(),
# #             }, f'stylegan_checkpoint_epoch_{epoch+1}.pth')
# # Import additional required library


# def train_stylegan(train_dir, test_dir, num_epochs=, batch_size=8):  # Reduced batch size
#     device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
#     # Initialize dataset with smaller image size
#     train_dataset = FaceDataset(train_dir, image_size=128)
#     train_loader = DataLoader(
#         train_dataset, 
#         batch_size=batch_size, 
#         shuffle=True,
#         num_workers=2,  # Reduced number of workers
#         pin_memory=True
#     )
    
#     generator = StyleGANGenerator().to(device)
#     discriminator = StyleGANDiscriminator().to(device)
    
#     # Use mixed precision training
#     scaler = GradScaler()
    
#     # Use different learning rates for generator and discriminator
#     g_optimizer = torch.optim.Adam(generator.parameters(), lr=0.0001, betas=(0.0, 0.99))
#     d_optimizer = torch.optim.Adam(discriminator.parameters(), lr=0.0001, betas=(0.0, 0.99))
    
#     # Learning rate schedulers
#     g_scheduler = torch.optim.lr_scheduler.ExponentialLR(g_optimizer, gamma=0.99)
#     d_scheduler = torch.optim.lr_scheduler.ExponentialLR(d_optimizer, gamma=0.99)
    
#     # Track losses for plotting
#     d_losses = []
#     g_losses = []
    
#     for epoch in range(num_epochs):
#         epoch_d_loss = 0
#         epoch_g_loss = 0
#         for batch_idx, real_images in enumerate(train_loader):
#             real_images = real_images.to(device)
#             batch_size = real_images.size(0)
            
#             # Clear cache periodically
#             if batch_idx % 10 == 0:
#                 torch.cuda.empty_cache()
            
#             # Train Discriminator
#             with autocast():
#                 d_optimizer.zero_grad()
                
#                 label_real = torch.ones(batch_size, 1).to(device)
#                 label_fake = torch.zeros(batch_size, 1).to(device)
                
#                 d_output_real = discriminator(real_images)
#                 d_loss_real = F.binary_cross_entropy_with_logits(d_output_real, label_real)
                
#                 z = torch.randn(batch_size, 512).to(device)
#                 fake_images = generator(z)
#                 d_output_fake = discriminator(fake_images.detach())
#                 d_loss_fake = F.binary_cross_entropy_with_logits(d_output_fake, label_fake)
                
#                 d_loss = d_loss_real + d_loss_fake
            
#             scaler.scale(d_loss).backward()
#             scaler.step(d_optimizer)
            
#             # Train Generator
#             with autocast():
#                 g_optimizer.zero_grad()
                
#                 d_output_fake = discriminator(fake_images)
#                 g_loss = F.binary_cross_entropy_with_logits(d_output_fake, label_real)
            
#             scaler.scale(g_loss).backward()
#             scaler.step(g_optimizer)
            
#             scaler.update()
            
#             # Accumulate losses
#             epoch_d_loss += d_loss.item()
#             epoch_g_loss += g_loss.item()
            
#             if batch_idx % 50 == 0:
#                 print(f'Epoch [{epoch}/{num_epochs}] Batch [{batch_idx}/{len(train_loader)}] '
#                       f'd_loss: {d_loss.item():.4f} g_loss: {g_loss.item():.4f}')
                
#                 # Clear some memory
#                 del d_loss, g_loss, fake_images, real_images
#                 torch.cuda.empty_cache()
        
#         # Average losses for the epoch
#         d_losses.append(epoch_d_loss / len(train_loader))
#         g_losses.append(epoch_g_loss / len(train_loader))
        
#         # Step the schedulers
#         g_scheduler.step()
#         d_scheduler.step()
        
#         # Save checkpoint with memory optimization
#         if (epoch + 1) % 10 == 0:
#             torch.save({
#                 'epoch': epoch,
#                 'generator_state_dict': generator.state_dict(),
#                 'discriminator_state_dict': discriminator.state_dict(),
#                 'g_optimizer_state_dict': g_optimizer.state_dict(),
#                 'd_optimizer_state_dict': d_optimizer.state_dict(),
#             }, f'stylegan_checkpoint_epoch_{epoch+1}.pth')
    
#     # Plot the loss curves
#     plt.figure(figsize=(10, 5))
#     plt.plot(d_losses, label='Discriminator Loss')
#     plt.plot(g_losses, label='Generator Loss')
#     plt.xlabel('Epochs')
#     plt.ylabel('Loss')
#     plt.legend()
#     plt.title('Training Loss Curve')
#     plt.show()

# def explore_latent_space(generator, n_samples=5, save_dir='generated_faces'):
#     device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#     generator.eval()
    
#     os.makedirs(save_dir, exist_ok=True)
    
#     with torch.no_grad():
#         z1 = torch.randn(1, 512).to(device)
#         z2 = torch.randn(1, 512).to(device)
        
#         for i in range(n_samples):
#             # Generate one image at a time to save memory
#             alpha = i / (n_samples - 1)
#             z = z1 * (1 - alpha) + z2 * alpha
            
#             fake_image = generator(z)
#             fake_image = (fake_image + 1) / 2
#             fake_image = fake_image.cpu().squeeze(0)
            
#             transforms.ToPILImage()(fake_image).save(
#                 os.path.join(save_dir, f'interpolation_{i}.jpg')
#             )
            
#             # Clear memory
#             del fake_image
#             torch.cuda.empty_cache()

# if __name__ == "__main__":
#     # Set memory optimization flags
#     torch.backends.cudnn.benchmark = True
#     torch.backends.cuda.matmul.allow_tf32 = True
#     torch.backends.cudnn.allow_tf32 = True
    
#     train_dir = "/kaggle/input/stylegan/STYLEGAN/train"
#     test_dir = "/kaggle/input/stylegan/STYLEGAN/test"
    
#     # Train with reduced batch size and image size
#     train_stylegan(train_dir, test_dir, batch_size=8)


# #Generate Sample Images from StyleGAN

# %%
import torch
import torchvision.utils as vutils
import matplotlib.pyplot as plt
from torchvision import transforms
import os

def generate_samples(checkpoint_path, num_samples=16, output_dir='generated_samples50'):
    """
    Generate and save sample images from a trained StyleGAN model
    """
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    # Load the trained generator
    generator = StyleGANGenerator().to(device)
    checkpoint = torch.load(checkpoint_path, map_location=device)
    generator.load_state_dict(checkpoint['generator_state_dict'])
    generator.eval()
    
    # Create output directory
    os.makedirs(output_dir, exist_ok=True)
    
    with torch.no_grad():
        # Generate random latent vectors
        z = torch.randn(num_samples, 512).to(device)
        
        # Generate images
        fake_images = generator(z)
        
        # Normalize images from [-1, 1] to [0, 1]
        fake_images = (fake_images + 1) / 2.0
        
        # Save individual images
        for i, image in enumerate(fake_images):
            img_path = os.path.join(output_dir, f'sample_{i+1}.png')
            vutils.save_image(image, img_path, normalize=False)
        
        # Create a grid of images
        grid = vutils.make_grid(fake_images, nrow=4, padding=2, normalize=False)
        grid_path = os.path.join(output_dir, 'samples_grid.png')
        vutils.save_image(grid, grid_path)
        
        # Display the grid
        plt.figure(figsize=(15, 15))
        plt.axis('off')
        plt.title('Generated Samples')
        plt.imshow(grid.cpu().permute(1, 2, 0))
        plt.savefig(os.path.join(output_dir, 'samples_6.png'))
        plt.close()

def create_style_mixing(checkpoint_path, num_samples=4, output_dir='style_mixing50'):
    """
    Generate images with mixed styles from different latent vectors
    """
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    # Load the trained generator
    generator = StyleGANGenerator().to(device)
    checkpoint = torch.load(checkpoint_path, map_location=device)
    generator.load_state_dict(checkpoint['generator_state_dict'])
    generator.eval()
    
    os.makedirs(output_dir, exist_ok=True)
    
    with torch.no_grad():
        # Generate two sets of latent vectors
        z1 = torch.randn(num_samples, 512).to(device)
        z2 = torch.randn(num_samples, 512).to(device)
        
        # Get their W representations
        w1 = generator.mapping(z1)
        w2 = generator.mapping(z2)
        
        # Generate original images
        images1 = generator(z1)
        images2 = generator(z2)
        
        # Create mixed styles
        w_mixed = w1.clone()
        w_mixed[:, len(generator.blocks)//2:] = w2[:, len(generator.blocks)//2:]
        
        # Generate mixed images
        images_mixed = generator(w_mixed)
        
        # Normalize images
        images1 = (images1 + 1) / 2
        images2 = (images2 + 1) / 2
        images_mixed = (images_mixed + 1) / 2
        
        # Create comparison grid
        all_images = torch.cat([images1, images2, images_mixed], dim=0)
        grid = vutils.make_grid(all_images, nrow=num_samples, padding=2, normalize=False)
        
        # Save grid
        vutils.save_image(grid, os.path.join(output_dir, 'style_mixing_grid.png'))
        
        # Display grid
        plt.figure(figsize=(15, 15))
        plt.axis('off')
        plt.title('Style Mixing Results\nTop: Source 1 | Middle: Source 2 | Bottom: Mixed')
        plt.imshow(grid.cpu().permute(1, 2, 0))
        plt.savefig(os.path.join(output_dir, 'style_mixing_display.png'))
        plt.close()

if __name__ == "__main__":
    checkpoint_path = "stylegan_checkpoint_epoch_50.pth"  # Adjust path as needed
    
    # Generate regular samples
    generate_samples(checkpoint_path, num_samples=16)
    
    # Generate style mixing examples
    create_style_mixing(checkpoint_path, num_samples=4)
# Out:
# /tmp/ipykernel_24/3791953543.py:15: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=device)
# /tmp/ipykernel_24/3791953543.py:58: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=device)

# %%
import os

# Folder path containing the saved images
folder_path = '/kaggle/working/generated_samples50/'

# Get the list of images
images = os.listdir(folder_path)

# Display the first image
image_path = os.path.join(folder_path, images[10])
img = Image.open(image_path)

# Display the image
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
import os

# Folder path containing the saved images
folder_path = '/kaggle/working/generated_samples50/'

# Get the list of images
images = os.listdir(folder_path)

# Display the first image
image_path = os.path.join(folder_path, images[2])
img = Image.open(image_path)

# Display the image
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
import os

# Folder path containing the saved images
folder_path = '/kaggle/working/style_mixing50/'

# Get the list of images
images = os.listdir(folder_path)

# Display the first image
image_path = os.path.join(folder_path, images[1])
img = Image.open(image_path)

# Display the image
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
import os

# Folder path containing the saved images
folder_path = '/kaggle/working/style_mixing50/'

# Get the list of images
images = os.listdir(folder_path)

# Display the first image
image_path = os.path.join(folder_path, images[0])
img = Image.open(image_path)

# Display the image
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
import torch
import torchvision.utils as vutils
import matplotlib.pyplot as plt
from torchvision import transforms
import os

def generate_samples(checkpoint_path, num_samples=16, output_dir='generated_samples100'):
    """
    Generate and save sample images from a trained StyleGAN model
    """
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    # Load the trained generator
    generator = StyleGANGenerator().to(device)
    checkpoint = torch.load(checkpoint_path, map_location=device)
    generator.load_state_dict(checkpoint['generator_state_dict'])
    generator.eval()
    
    # Create output directory
    os.makedirs(output_dir, exist_ok=True)
    
    with torch.no_grad():
        # Generate random latent vectors
        z = torch.randn(num_samples, 512).to(device)
        
        # Generate images
        fake_images = generator(z)
        
        # Normalize images from [-1, 1] to [0, 1]
        fake_images = (fake_images + 1) / 2.0
        
        # Save individual images
        for i, image in enumerate(fake_images):
            img_path = os.path.join(output_dir, f'sample_{i+1}.png')
            vutils.save_image(image, img_path, normalize=False)
        
        # Create a grid of images
        grid = vutils.make_grid(fake_images, nrow=4, padding=2, normalize=False)
        grid_path = os.path.join(output_dir, 'samples_grid.png')
        vutils.save_image(grid, grid_path)
        
        # Display the grid
        plt.figure(figsize=(15, 15))
        plt.axis('off')
        plt.title('Generated Samples')
        plt.imshow(grid.cpu().permute(1, 2, 0))
        plt.savefig(os.path.join(output_dir, 'samples_6.png'))
        plt.close()

def create_style_mixing(checkpoint_path, num_samples=4, output_dir='style_mixing100'):
    """
    Generate images with mixed styles from different latent vectors
    """
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    # Load the trained generator
    generator = StyleGANGenerator().to(device)
    checkpoint = torch.load(checkpoint_path, map_location=device)
    generator.load_state_dict(checkpoint['generator_state_dict'])
    generator.eval()
    
    os.makedirs(output_dir, exist_ok=True)
    
    with torch.no_grad():
        # Generate two sets of latent vectors
        z1 = torch.randn(num_samples, 512).to(device)
        z2 = torch.randn(num_samples, 512).to(device)
        
        # Get their W representations
        w1 = generator.mapping(z1)
        w2 = generator.mapping(z2)
        
        # Generate original images
        images1 = generator(z1)
        images2 = generator(z2)
        
        # Create mixed styles
        w_mixed = w1.clone()
        w_mixed[:, len(generator.blocks)//2:] = w2[:, len(generator.blocks)//2:]
        
        # Generate mixed images
        images_mixed = generator(w_mixed)
        
        # Normalize images
        images1 = (images1 + 1) / 2
        images2 = (images2 + 1) / 2
        images_mixed = (images_mixed + 1) / 2
        
        # Create comparison grid
        all_images = torch.cat([images1, images2, images_mixed], dim=0)
        grid = vutils.make_grid(all_images, nrow=num_samples, padding=2, normalize=False)
        
        # Save grid
        vutils.save_image(grid, os.path.join(output_dir, 'style_mixing_grid.png'))
        
        # Display grid
        plt.figure(figsize=(15, 15))
        plt.axis('off')
        plt.title('Style Mixing Results\nTop: Source 1 | Middle: Source 2 | Bottom: Mixed')
        plt.imshow(grid.cpu().permute(1, 2, 0))
        plt.savefig(os.path.join(output_dir, 'style_mixing_display.png'))
        plt.close()

if __name__ == "__main__":
    checkpoint_path = "stylegan_checkpoint_epoch_100.pth"  # Adjust path as needed
    
    # Generate regular samples
    generate_samples(checkpoint_path, num_samples=16)
    
    # Generate style mixing examples
    create_style_mixing(checkpoint_path, num_samples=4)
# Out:
# /tmp/ipykernel_24/4181057530.py:15: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=device)
# /tmp/ipykernel_24/4181057530.py:58: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=device)

# %%
import os

# Folder path containing the saved images
folder_path = '/kaggle/working/style_mixing100/'

# Get the list of images
images = os.listdir(folder_path)

# Display the first image
image_path = os.path.join(folder_path, images[0])
img = Image.open(image_path)

# Display the image
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
import os

# Folder path containing the saved images
folder_path = '/kaggle/working/generated_samples100/'

# Get the list of images
images = os.listdir(folder_path)

# Display the first image
image_path = os.path.join(folder_path, images[2])
img = Image.open(image_path)

# Display the image
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
import torch
import torchvision.utils as vutils
import matplotlib.pyplot as plt
from torchvision import transforms
import os

def generate_samples(checkpoint_path, num_samples=16, output_dir='generated_samples200'):
    """
    Generate and save sample images from a trained StyleGAN model
    """
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    # Load the trained generator
    generator = StyleGANGenerator().to(device)
    checkpoint = torch.load(checkpoint_path, map_location=device)
    generator.load_state_dict(checkpoint['generator_state_dict'])
    generator.eval()
    
    # Create output directory
    os.makedirs(output_dir, exist_ok=True)
    
    with torch.no_grad():
        # Generate random latent vectors
        z = torch.randn(num_samples, 512).to(device)
        
        # Generate images
        fake_images = generator(z)
        
        # Normalize images from [-1, 1] to [0, 1]
        fake_images = (fake_images + 1) / 2.0
        
        # Save individual images
        for i, image in enumerate(fake_images):
            img_path = os.path.join(output_dir, f'sample_{i+1}.png')
            vutils.save_image(image, img_path, normalize=False)
        
        # Create a grid of images
        grid = vutils.make_grid(fake_images, nrow=4, padding=2, normalize=False)
        grid_path = os.path.join(output_dir, 'samples_grid.png')
        vutils.save_image(grid, grid_path)
        
        # Display the grid
        plt.figure(figsize=(15, 15))
        plt.axis('off')
        plt.title('Generated Samples')
        plt.imshow(grid.cpu().permute(1, 2, 0))
        plt.savefig(os.path.join(output_dir, 'samples_6.png'))
        plt.close()

def create_style_mixing(checkpoint_path, num_samples=4, output_dir='style_mixing200'):
    """
    Generate images with mixed styles from different latent vectors
    """
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    # Load the trained generator
    generator = StyleGANGenerator().to(device)
    checkpoint = torch.load(checkpoint_path, map_location=device)
    generator.load_state_dict(checkpoint['generator_state_dict'])
    generator.eval()
    
    os.makedirs(output_dir, exist_ok=True)
    
    with torch.no_grad():
        # Generate two sets of latent vectors
        z1 = torch.randn(num_samples, 512).to(device)
        z2 = torch.randn(num_samples, 512).to(device)
        
        # Get their W representations
        w1 = generator.mapping(z1)
        w2 = generator.mapping(z2)
        
        # Generate original images
        images1 = generator(z1)
        images2 = generator(z2)
        
        # Create mixed styles
        w_mixed = w1.clone()
        w_mixed[:, len(generator.blocks)//2:] = w2[:, len(generator.blocks)//2:]
        
        # Generate mixed images
        images_mixed = generator(w_mixed)
        
        # Normalize images
        images1 = (images1 + 1) / 2
        images2 = (images2 + 1) / 2
        images_mixed = (images_mixed + 1) / 2
        
        # Create comparison grid
        all_images = torch.cat([images1, images2, images_mixed], dim=0)
        grid = vutils.make_grid(all_images, nrow=num_samples, padding=2, normalize=False)
        
        # Save grid
        vutils.save_image(grid, os.path.join(output_dir, 'style_mixing_grid.png'))
        
        # Display grid
        plt.figure(figsize=(15, 15))
        plt.axis('off')
        plt.title('Style Mixing Results\nTop: Source 1 | Middle: Source 2 | Bottom: Mixed')
        plt.imshow(grid.cpu().permute(1, 2, 0))
        plt.savefig(os.path.join(output_dir, 'style_mixing_display.png'))
        plt.close()

if __name__ == "__main__":
    checkpoint_path = "stylegan_checkpoint_epoch_200.pth"  # Adjust path as needed
    
    # Generate regular samples
    generate_samples(checkpoint_path, num_samples=16)
    
    # Generate style mixing examples
    create_style_mixing(checkpoint_path, num_samples=4)
# Out:
# /tmp/ipykernel_24/1368374539.py:15: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=device)
# /tmp/ipykernel_24/1368374539.py:58: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=device)

# %%
import os

# Folder path containing the saved images
folder_path = '/kaggle/working/style_mixing200/'

# Get the list of images
images = os.listdir(folder_path)

# Display the first image
image_path = os.path.join(folder_path, images[0])
img = Image.open(image_path)

# Display the image
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
import os

# Folder path containing the saved images
folder_path = '/kaggle/working/generated_samples200/'

# Get the list of images
images = os.listdir(folder_path)

# Display the first image
image_path = os.path.join(folder_path, images[2])
img = Image.open(image_path)

# Display the image
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# # Import additional required library
# import matplotlib.pyplot as plt

# def train_stylegan(train_dir, test_dir, num_epochs=100, batch_size=8):  # Reduced batch size
#     device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
#     # Initialize dataset with smaller image size
#     train_dataset = FaceDataset(train_dir, image_size=128)
#     train_loader = DataLoader(
#         train_dataset, 
#         batch_size=batch_size, 
#         shuffle=True,
#         num_workers=2,  # Reduced number of workers
#         pin_memory=True
#     )
    
#     generator = StyleGANGenerator().to(device)
#     discriminator = StyleGANDiscriminator().to(device)
    
#     # Use mixed precision training
#     scaler = GradScaler()
    
#     # Use different learning rates for generator and discriminator
#     g_optimizer = torch.optim.Adam(generator.parameters(), lr=0.0001, betas=(0.0, 0.99))
#     d_optimizer = torch.optim.Adam(discriminator.parameters(), lr=0.0001, betas=(0.0, 0.99))
    
#     # Learning rate schedulers
#     g_scheduler = torch.optim.lr_scheduler.ExponentialLR(g_optimizer, gamma=0.99)
#     d_scheduler = torch.optim.lr_scheduler.ExponentialLR(d_optimizer, gamma=0.99)
    
#     # Track losses for plotting
#     d_losses = []
#     g_losses = []
    
#     for epoch in range(num_epochs):
#         epoch_d_loss = 0
#         epoch_g_loss = 0
#         for batch_idx, real_images in enumerate(train_loader):
#             real_images = real_images.to(device)
#             batch_size = real_images.size(0)
            
#             # Clear cache periodically
#             if batch_idx % 10 == 0:
#                 torch.cuda.empty_cache()
            
#             # Train Discriminator
#             with autocast():
#                 d_optimizer.zero_grad()
                
#                 label_real = torch.ones(batch_size, 1).to(device)
#                 label_fake = torch.zeros(batch_size, 1).to(device)
                
#                 d_output_real = discriminator(real_images)
#                 d_loss_real = F.binary_cross_entropy_with_logits(d_output_real, label_real)
                
#                 z = torch.randn(batch_size, 512).to(device)
#                 fake_images = generator(z)
#                 d_output_fake = discriminator(fake_images.detach())
#                 d_loss_fake = F.binary_cross_entropy_with_logits(d_output_fake, label_fake)
                
#                 d_loss = d_loss_real + d_loss_fake
            
#             scaler.scale(d_loss).backward()
#             scaler.step(d_optimizer)
            
#             # Train Generator
#             with autocast():
#                 g_optimizer.zero_grad()
                
#                 d_output_fake = discriminator(fake_images)
#                 g_loss = F.binary_cross_entropy_with_logits(d_output_fake, label_real)
            
#             scaler.scale(g_loss).backward()
#             scaler.step(g_optimizer)
            
#             scaler.update()
            
#             # Accumulate losses
#             epoch_d_loss += d_loss.item()
#             epoch_g_loss += g_loss.item()
            
#             if batch_idx % 50 == 0:
#                 print(f'Epoch [{epoch}/{num_epochs}] Batch [{batch_idx}/{len(train_loader)}] '
#                       f'd_loss: {d_loss.item():.4f} g_loss: {g_loss.item():.4f}')
                
#                 # Clear some memory
#                 del d_loss, g_loss, fake_images, real_images
#                 torch.cuda.empty_cache()
        
#         # Average losses for the epoch
#         d_losses.append(epoch_d_loss / len(train_loader))
#         g_losses.append(epoch_g_loss / len(train_loader))
        
#         # Step the schedulers
#         g_scheduler.step()
#         d_scheduler.step()
        
#         # Save checkpoint with memory optimization
#         if (epoch + 1) % 10 == 0:
#             torch.save({
#                 'epoch': epoch,
#                 'generator_state_dict': generator.state_dict(),
#                 'discriminator_state_dict': discriminator.state_dict(),
#                 'g_optimizer_state_dict': g_optimizer.state_dict(),
#                 'd_optimizer_state_dict': d_optimizer.state_dict(),
#             }, f'stylegan_checkpoint_epoch_{epoch+1}.pth')
    
#     # Plot the loss curves
#     plt.figure(figsize=(10, 5))
#     plt.plot(d_losses, label='Discriminator Loss')
#     plt.plot(g_losses, label='Generator Loss')
#     plt.xlabel('Epochs')
#     plt.ylabel('Loss')
#     plt.legend()
#     plt.title('Training Loss Curve')
#     plt.show()
